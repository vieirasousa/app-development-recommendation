# %% [markdown]
# # An analysis on Apps Stores: most profitable apps available on march 2019
#
# In this project we will present you some insights on the most downloaded (and the most profitable ones, as a consequence) apps on mobile app stores.
#
# Our main objective is to help our team to understand what kinds of apps are likely to attract more users on the Google Play Store and Apple Apps Store, so we can make data driven decisions about what types of application are likely to create more revenue once developed and distributed.
#
# For both systems there's a huge collection of apps available, about 2 million apps on the App Store and 2,1 million on Google Play Store. Such large universe would be impractical to analyse, since it would require too much time spent on data cleasing, and extra costs aquiring such dataset.
#
# Thus, bearing in mind the statistics principle of sampling, we've opted for using two free datasets, one for each platform, still containing a good deal of apps, large enough to
#
# We got this number using a free dataset which is available [here](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps)
#
# That dataset is organized in columns, and described as follows:
#
# | Column | Description |
# |---|---|
# |"id" | App ID |
# | "track_name" | App Name |
# | "size_bytes" | Size (in Bytes) |
# | "currency" | Currency Type |
# | "price" | Price amount |
# | "rating_count_tot" | User Rating counts (for all version) |
# | "rating_count_ver" | User Rating counts (for current version) |
# | "user_rating" | Average User Rating value (for all version) |
# | "user_rating_ver" | Average User Rating value (for current version) |
# | "ver" | Latest version code |
# | "cont_rating" | Content Rating |
# | "prime_genre" | Primary Genre |
# | "sup_devices.num" | Number of supporting devices |
# | "ipadSc_urls.num" | Number of screenshots showed for display |
# | "lang.num" | Number of supported languages |
# | "vpp_lic" | Vpp Device Based Licensing Enabled |
#
#
# For Android the columns are quite self-explanatory:
#
# | Column |
# |---|
# |App|
# |Category|
# |Rating|
# |Reviews|
# |Size|
# |Installs|
# |Type|
# |Price|
# |Content Rating|
# |Genres|
# |Last Updated|
# |Current Ver|
# |Android Ver|

# %% [markdown]
# **We will start exploring the datasets by importing a function called *reader*, from the **CSV library**, which means *comma separated values*, a general use format for importing datasheets and lists organized in columns and rows. Further, we open and load each file in a format that can be manipulated with Python commands.**

# %%
from csv import reader

opened_file_apple = open('AppleStore.csv')
read_apple = reader(opened_file_apple)
apple_apps_data = list(read_apple)

opened_file_android = open('googleplaystore.csv')
read_android = reader(opened_file_android)
android_apps_data = list(read_android)

# %% [markdown]
# **Now, we're going to import a function that organizes dictionaries (a special kind of data list) in decreasing order. Its use we'll see much  further on this work.**

# %%
from collections import OrderedDict

# %% [markdown]
# **Here, after we loaded the datasets, we print the first row in each one. Our objective is to show what information is available on those tables. For greater convenience, we also created two variables with the rows, which we will use many times for reference.**

# %%
android_header = (android_apps_data[0])
print (android_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
apple_header = (apple_apps_data[0])
print (apple_header)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# **We've created a simple function for exploring the datasets, which can be seen below:**

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %% [markdown]
# **And here we use that function with the two datasets.**

# %%
explore_data(apple_apps_data, 1, 4, rows_and_columns=True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 7198
# Number of columns: 16

# %%
explore_data(android_apps_data, 1, 4, rows_and_columns=True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10842
# Number of columns: 13

# %% [markdown]
# **With further analysis on these datasets we've found apps that lacked information, and redundant apps. If not rectified, those occurences would create statistical distortions and make this work less reliable.**
#
# **So, we had to cleanse the sets, removing duplicates and items which lacked information.**

# %% [markdown]
# **Below, we start the data cleansing, removing from the Android list an app that lacked an important column for our analysis.**

# %%
index = 0
for row in android_apps_data[1:]:
    index += 1
    app_name = row[0]
    if app_name == 'Life Made WI-Fi Touchscreen Photo Frame':
        print (row)
        print (index)
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
# 10473

# %%
del android_apps_data[10473]

# %% [markdown]
# **Now we check for duplicates on the Android dataset, creating two lists, one for unique registers, and one for duplicated ones.**

# %%
unique_android = []
duplicated_android = []

for row in android_apps_data[1:]:
    name = row[0]
    if name in unique_android:
        duplicated_android.append(name)
    else:
        unique_android.append(name)

# %% [markdown]
# **We'll do the same for the iOS dataset.**

# %%
unique_ios = []
duplicated_ios = []

for row in apple_apps_data[1:]:
    name = row[1]
    if name in unique_ios:
        duplicated_ios.append(name)
    else:
        unique_ios.append(name)

# %% [markdown]
# **As we do this checking, we found 1.181 duplicated items in Android dataset, from a total of 10.840. This redundances represent more than 10% of the registers and given its weight, it could lead to wrong conclusions further.**
#
# **For Apple dataset, we've found 2 redundances, which could be ignored without trouble for our final results.**

# %%
and_dupl_num = len (duplicated_android)
and_uniq_num = len (unique_android)
ios_dupl_num = len (duplicated_ios)
ios_uniq_num = len (unique_ios)

print (and_dupl_num)
print (and_uniq_num)
print (ios_dupl_num)
print (ios_uniq_num)
# Out:
# 1181
# 9659
# 2
# 7195

# %% [markdown]
# **Here's some of these redundances we've found in Android set:**

# %%
print (duplicated_android[:10])
# Out:
# ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings', 'Box', 'Zenefits', 'Google Ads', 'Google My Business', 'Slack']

# %% [markdown]
# **Many of these redundances have columns with different values, so we can not just randomly them. Instagram duplicated registries, for example, have different values on the 4th column, which holds the total number of reviews for a given app:**

# %%
for row in android_apps_data[1:]:
    name = row[0]
    if name == 'Instagram':
        print (row)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']

# %% [markdown]
# **We came to conclusion that there's a relation amongst the numbers on that columns: they have a growing pattern what indicates the growing number of reviews for that app, so we just kept the largest number (as it would indicate the latest value) and removed the smaller ones**

# %%
reviews_max = {}

for row in android_apps_data[1:]:
    name = row[0]
    n_reviews = float(row[3])
    if name not in reviews_max:
        reviews_max[name] = n_reviews
    if name in reviews_max:
        if n_reviews > reviews_max[name]:
            reviews_max[name] = n_reviews

# %% [markdown]
# **Now we can check the "reviews_max" dictionary length, which contains no duplicated items. We expect it to match the unique values number of 9656, as seen on the first checking for duplicates**

# %%
len (reviews_max)
# Out:
# 9659

# %% [markdown]
# **It matches the number we've found on the first checking. Now we're going to clear our main list.**

# %%
android_clean = []
apple_clean = apple_apps_data[1:]
already_added = []

for row in android_apps_data[1:]:
    name = row[0]
    n_reviews = float(row[3])
    if n_reviews == reviews_max[name]:
        if name not in already_added:
            android_clean.append(row)
            already_added.append(name)

# %% [markdown]
# **Let's check if the new list matches the numbers of unique apps and explore it a bit**

# %%
len (android_clean)
# Out:
# 9659

# %% [markdown]
# **The list length is ok. Now with the exploring:**

# %%
explore_data(android_clean, 1, 7)
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']
#
#
# ['Infinite Painter', 'ART_AND_DESIGN', '4.1', '36815', '29M', '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'June 14, 2018', '6.1.61.1', '4.2 and up']

# %% [markdown]
# **Now, we're going to check the list of apps added to the clean list, just to make sure it corresponds the number of unique apps, and explore it a litte, to confirm its content.**

# %%
len (already_added)
print (already_added[1:6])
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'Sketch - Draw & Paint', 'Pixel Draw - Number Art Coloring Book', 'Paper flowers instructions', 'Smoke Effect Photo Maker - Smoke Editor']

# %% [markdown]
# **Everything seems ok. Now it's time to remove apps with non-latin characters, since our reasearch is about apps that could make a profit on Western countries.**
#
# **This can be made by using the ASCII system codification to characters, where every character has a corresponding number, and where the latin characters range from 0 to 127**
#
# **In Python, there's a built-in function to check a character's ASCII corresponding number, which is "ord". We're going to use this to check if a app name has non-latin characters, and if it is the case, we're remove that app from our list, as follows.**

# %%
def check_latin (app_name):
    latin_char = []
    non_latin_char = []
    for char in app_name:
        if ord(char) < 128:
            latin_char.append(char)
        if ord(char) > 127:
            non_latin_char.append(char)
    
    len_latin = len (latin_char)
    len_non_latin = len (non_latin_char)
    if len_latin > len_non_latin:
        return True
    else:
        return False

real_clean_googleapps = []
for row in android_clean[1:]:
    ck = check_latin(row[0])
    if ck == True:
        real_clean_googleapps.append(row)
        
real_clean_appleapps = []
for row in apple_clean[1:]:
    chk = check_latin(row[1])
    if chk == True:
        real_clean_appleapps.append(row)

# %% [markdown]
# **Now, we're gonna check the ultimate clean lists lengths, just to make sure everything looks right**

# %%
goog_len = len (real_clean_googleapps)
appl_len = len (real_clean_appleapps)
print (goog_len)
print (appl_len)
# Out:
# 9632
# 6226

# %% [markdown]
# **A brief look at these dataset revealed that free to use apps, which rely on ads to profit, are the most numerous and downloaded ones. We created a simple program to show this.**

# %%
apple_apps_prices = {'Free': 0, 'Non_free': 0}
apple_apps_downloads = {'Free': 0, 'Non_free': 0}
for row in real_clean_appleapps:
    price = float (row[4])
    downloaded_times = float (row[5])
    if price == 0.0:
        apple_apps_prices['Free'] += 1
        apple_apps_downloads['Free'] += downloaded_times
    else:
        apple_apps_prices['Non_free'] += 1
        apple_apps_downloads['Non_free'] += downloaded_times

total_apps = apple_apps_prices['Free'] + apple_apps_prices['Non_free']
total_downloads = apple_apps_downloads['Free'] + apple_apps_downloads['Non_free']

# %% [markdown]
# **And below, you can see the numbers. In this sample, there are 4.056 free apps, downloaded 80.105.208 times, and 3.141 paid apps, downloaded 12.685.045 times.**

# %%
print (apple_apps_prices)
# Out:
# {'Free': 3253, 'Non_free': 2973}

# %%
print (apple_apps_downloads)
# Out:
# {'Free': 77011249.0, 'Non_free': 12680532.0}

# %% [markdown]
# **We can have a better notion in percentual terms, as we see below:**

# %%
apple_free_apps_propor = (apple_apps_prices['Free']/total_apps)*100
apple_free_downloads = (apple_apps_downloads['Free']/total_downloads)*100

# %%
proporcao_apps = round(apple_free_apps_propor)
proporcao_downloads = round (apple_free_downloads)
print (proporcao_apps)
print (proporcao_downloads)
# Out:
# 52
# 86

# %% [markdown]
# **As we can see, free apps represent 56% of total apps and 86% of all downloads in iOS App Store.**

# %% [markdown]
# **Now it's time to isolate free apps on the two apps stores. Let's check again the header rows to get the indexes of prices**

# %%
print (android_apps_data[0])
print (apple_apps_data[0])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# **As we see, the indexes are [7] for Android Apps and [4] for iOS Apps. Let's check the ultimate clean lists to confirm.**

# %%
print (real_clean_googleapps[0])
print (real_clean_appleapps[0])
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']

# %% [markdown]
# **Everything looks fine. Now we're going to isolate the free apps on the two datasets.**

# %%
android_free = []
android_non_free = []
ios_free = []
ios_non_free = []

for row in real_clean_googleapps:
    price = row[6]
    if price == 'Free':
        android_free.append(row)
    else:
        android_non_free.append(row)
    
    
for row in real_clean_appleapps:
    price = row[4]
    if price == '0.0':
        ios_free.append(row)
    else:
        ios_non_free.append(row)

# %% [markdown]
# **Let's explore the free datasets, starting by Android**

# %%
explore_data(android_free, 0, 5)
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']

# %% [markdown]
# **Now, with the iOS dataset**

# %%
explore_data(ios_free, 0, 5)
# Out:
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# ['284035177', 'Pandora - Music & Radio', '130242560', 'USD', '0.0', '1126879', '3594', '4.0', '4.5', '8.4.1', '12+', 'Music', '37', '4', '1', '1']
#
#
# ['429047995', 'Pinterest', '74778624', 'USD', '0.0', '1061624', '1814', '4.5', '4.0', '6.26', '12+', 'Social Networking', '37', '5', '27', '1']

# %% [markdown]
# **Now we're going to check the lenghts of the two free and non free datasets**

# %%
len_free_ios = len (ios_free)
print (len_free_ios)

len_non_free_ios = len (ios_non_free)
print (len_non_free_ios)
# Out:
# 3253
# 2973

# %%
len_free_and = len (android_free)
print (len_free_and)

len_non_free_and = len (android_non_free)
print (len_non_free_and)
# Out:
# 8878
# 754

# %% [markdown]
# **Everything seems fine so far.**

# %% [markdown]
# **To minimize risks on the development of apps, we have to have a validation strategy. We suggest the following steps:**
#
# 1. Build a minimal version of the app, only for Android, and add it to Google Play Store, since that platform costs for uploading an app is minimal, around US$ 25 one time payment.
#
# 2. We'll monitor the version performance amongst users. If the performance is good, we can develop the app further.
#
# 3. After six months, if the app shows profitable, we build and iOS version. This is necessary since there are bigger costs involved on uploading an app there.

# %% [markdown]
# **We'll now create a function to make a frequency table, where we can look up the sum of every occurence of a genre**

# %%
def freq_table (dataset, index, frequency=True):
    table = {}
    total = 0
    
    for row in dataset:
        total += 1
        
        value = row[index]
        if value not in table:
            table[value] = 1
        if value in table:
            table[value] += 1
    
    percent_tab = {}
    for key in table:
        percentage = (float (table[key])/total)*100
        percent_tab[key] = percentage
        
    if frequency == True:
        return (table)
    if frequency == False:
        return (percent_tab)

# %% [markdown]
# **Below, we create another function to order the genres by their number of occurences in a descending order, from the largest to the smallest.**

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)
    
    table_sorted = sorted (table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %% [markdown]
# **Now we use the functions to check the frequency of genres on the two datasets**

# %%
display_table(android_free, 1)
# Out:
# FAMILY : 1681
# GAME : 864
# TOOLS : 751
# BUSINESS : 409
# LIFESTYLE : 349
# PRODUCTIVITY : 347
# FINANCE : 329
# MEDICAL : 314
# SPORTS : 302
# PERSONALIZATION : 296
# COMMUNICATION : 288
# HEALTH_AND_FITNESS : 274
# PHOTOGRAPHY : 262
# NEWS_AND_MAGAZINES : 251
# SOCIAL : 237
# TRAVEL_AND_LOCAL : 208
# SHOPPING : 200
# BOOKS_AND_REFERENCE : 193
# DATING : 166
# VIDEO_PLAYERS : 160
# MAPS_AND_NAVIGATION : 126
# FOOD_AND_DRINK : 111
# EDUCATION : 104
# ENTERTAINMENT : 86
# LIBRARIES_AND_DEMO : 84
# AUTO_AND_VEHICLES : 83
# HOUSE_AND_HOME : 74
# WEATHER : 72
# EVENTS : 64
# PARENTING : 59
# ART_AND_DESIGN : 57
# COMICS : 56
# BEAUTY : 54

# %%
android_genre_qt = display_table(android_free, 9)
# Out:
# Tools : 750
# Entertainment : 541
# Education : 476
# Business : 409
# Lifestyle : 348
# Productivity : 347
# Finance : 329
# Medical : 314
# Sports : 308
# Personalization : 296
# Communication : 288
# Action : 276
# Health & Fitness : 274
# Photography : 262
# News & Magazines : 251
# Social : 237
# Travel & Local : 207
# Shopping : 200
# Books & Reference : 193
# Simulation : 182
# Dating : 166
# Arcade : 165
# Video Players & Editors : 158
# Casual : 157
# Maps & Navigation : 126
# Food & Drink : 111
# Puzzle : 101
# Racing : 89
# Role Playing : 84
# Libraries & Demo : 84
# Auto & Vehicles : 83
# Strategy : 82
# House & Home : 74
# Weather : 72
# Events : 64
# Adventure : 62
# Comics : 55
# Beauty : 54
# Art & Design : 53
# Parenting : 45
# Card : 41
# Casino : 39
# Trivia : 38
# Educational;Education : 36
# Board : 35
# Educational : 34
# Education;Education : 32
# Word : 24
# Casual;Pretend Play : 22
# Music : 19
# Racing;Action & Adventure : 16
# Puzzle;Brain Games : 16
# Entertainment;Music & Video : 16
# Casual;Brain Games : 13
# Casual;Action & Adventure : 13
# Arcade;Action & Adventure : 12
# Action;Action & Adventure : 10
# Educational;Pretend Play : 9
# Simulation;Action & Adventure : 8
# Parenting;Education : 8
# Entertainment;Brain Games : 8
# Board;Brain Games : 8
# Parenting;Music & Video : 7
# Educational;Brain Games : 7
# Casual;Creativity : 7
# Art & Design;Creativity : 7
# Education;Pretend Play : 6
# Role Playing;Pretend Play : 5
# Education;Creativity : 5
# Role Playing;Action & Adventure : 4
# Puzzle;Action & Adventure : 4
# Entertainment;Creativity : 4
# Entertainment;Action & Adventure : 4
# Educational;Creativity : 4
# Educational;Action & Adventure : 4
# Education;Music & Video : 4
# Education;Brain Games : 4
# Education;Action & Adventure : 4
# Adventure;Action & Adventure : 4
# Video Players & Editors;Music & Video : 3
# Sports;Action & Adventure : 3
# Simulation;Pretend Play : 3
# Puzzle;Creativity : 3
# Music;Music & Video : 3
# Entertainment;Pretend Play : 3
# Casual;Education : 3
# Board;Action & Adventure : 3
# Video Players & Editors;Creativity : 2
# Trivia;Education : 2
# Travel & Local;Action & Adventure : 2
# Tools;Education : 2
# Strategy;Education : 2
# Strategy;Creativity : 2
# Strategy;Action & Adventure : 2
# Simulation;Education : 2
# Role Playing;Brain Games : 2
# Racing;Pretend Play : 2
# Puzzle;Education : 2
# Parenting;Brain Games : 2
# Music & Audio;Music & Video : 2
# Lifestyle;Pretend Play : 2
# Lifestyle;Education : 2
# Health & Fitness;Education : 2
# Health & Fitness;Action & Adventure : 2
# Entertainment;Education : 2
# Communication;Creativity : 2
# Comics;Creativity : 2
# Casual;Music & Video : 2
# Card;Action & Adventure : 2
# Books & Reference;Education : 2
# Art & Design;Pretend Play : 2
# Art & Design;Action & Adventure : 2
# Arcade;Pretend Play : 2
# Adventure;Education : 2

# %%
ios_genre_qt = display_table (ios_free, 11)
# Out:
# Games : 1890
# Entertainment : 262
# Photo & Video : 163
# Education : 119
# Social Networking : 105
# Shopping : 86
# Utilities : 82
# Sports : 70
# Music : 67
# Health & Fitness : 66
# Productivity : 58
# Lifestyle : 52
# News : 45
# Travel : 41
# Finance : 37
# Food & Drink : 31
# Weather : 29
# Reference : 19
# Business : 18
# Book : 16
# Medical : 8
# Navigation : 7
# Catalogs : 5

# %% [markdown]
# **As we can see, "Games", "Entertainment", "Education", "Family" and "Tools" categories are the ones with more apps on the two datasets. But what are the most downloaded ones, proportionally? The average installation number by genre could show us this.**

# %% [markdown]
# **Android apps list has an "installs" column, we could use it for our analysis. But Apple apps list has no similar field, which leaves us with no choice besides using the "rating_count_tot" for measuring the number of times an app has been used and therefore rated by the users.**

# %% [markdown]
# **Now we're going to explore the Android installs column. But first, it need some cleansing on its values, since there are many of them presented with commas, plus simbols and others, as we can see below. The "installs" number can be seen on index 5**

# %%
explore_data(android_free, 0, 5)
# Out:
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# ['Paper flowers instructions', 'ART_AND_DESIGN', '4.4', '167', '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'March 26, 2017', '1.0', '2.3 and up']
#
#
# ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', '3.8', '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design', 'April 26, 2018', '1.1', '4.0.3 and up']

# %%
android_installs_genre = {}

for row in android_free:
    genre = row[9]
    
    installs = row[5]
    installs = installs.replace(',','')
    installs = installs.replace('+','')
    installs = float(installs)
    
    if genre not in android_installs_genre:
        android_installs_genre[genre] = installs
    
    if genre in android_installs_genre:
        android_installs_genre[genre] += installs

# %% [markdown]
# **Now we have the number of times each genre was downloaded. With the function "sorted', let's check the occurences on new dictionary we created and the greatest values there.**

# %%
sorted(android_installs_genre.items(), key=lambda x: (-x[1], x[0]))
# Out:
# [('Communication', 12036906201.0),
#  ('Tools', 9091043474.0),
#  ('Social', 6487861902.0),
#  ('Productivity', 6291679314.0),
#  ('Video Players & Editors', 4916731720.0),
#  ('Photography', 4657268815.0),
#  ('Arcade', 3853691940.0),
#  ('Action', 3470986940.0),
#  ('Casual', 3057798570.0),
#  ('Entertainment', 3015322513.0),
#  ('Travel & Local', 2944604086.0),
#  ('News & Magazines', 2378207260.0),
#  ('Books & Reference', 1665985260.0),
#  ('Personalization', 1579235988.0),
#  ('Sports', 1421230683.0),
#  ('Shopping', 1410338585.0),
#  ('Racing', 1410136820.0),
#  ('Health & Fitness', 1144048402.0),
#  ('Strategy', 917192105.0),
#  ('Puzzle', 880286191.0),
#  ('Business', 706952090.0),
#  ('Simulation', 679062620.0),
#  ('Maps & Navigation', 603160780.0),
#  ('Lifestyle', 497584429.0),
#  ('Finance', 465163132.0),
#  ('Weather', 410288520.0),
#  ('Adventure', 395417120.0),
#  ('Role Playing', 334148570.0),
#  ('Education', 261887900.0),
#  ('Casual;Action & Adventure', 255000000.0),
#  ('Trivia', 228601370.0),
#  ('Music', 220020500.0),
#  ('Word', 219172550.0),
#  ('Food & Drink', 211788751.0),
#  ('Casual;Pretend Play', 196100000.0),
#  ('Board', 166813110.0),
#  ('Card', 162618500.0),
#  ('Dating', 150914757.0),
#  ('Puzzle;Brain Games', 144210000.0),
#  ('Education;Education', 143795510.0),
#  ('Racing;Action & Adventure', 142250000.0),
#  ('Casino', 130360600.0),
#  ('Art & Design', 117501100.0),
#  ('House & Home', 107202461.0),
#  ('Adventure;Action & Adventure', 107000000.0),
#  ('Entertainment;Music & Video', 96700000.0),
#  ('Educational;Pretend Play', 85000000.0),
#  ('Action;Action & Adventure', 63000000.0),
#  ('Educational;Education', 61800010.0),
#  ('Puzzle;Action & Adventure', 60100000.0),
#  ('Auto & Vehicles', 53180061.0),
#  ('Libraries & Demo', 53045810.0),
#  ('Educational;Action & Adventure', 52050000.0),
#  ('Comics', 45421150.0),
#  ('Simulation;Action & Adventure', 44000000.0),
#  ('Casual;Creativity', 42000000.0),
#  ('Medical', 38732344.0),
#  ('Arcade;Action & Adventure', 35600001.0),
#  ('Role Playing;Action & Adventure', 31000000.0),
#  ('Beauty', 27697050.0),
#  ('Educational;Brain Games', 27600000.0),
#  ('Casual;Brain Games', 27111000.0),
#  ('Video Players & Editors;Music & Video', 25000000.0),
#  ('Entertainment;Brain Games', 24200000.0),
#  ('Role Playing;Pretend Play', 21200000.0),
#  ('Education;Brain Games', 21000000.0),
#  ('Parenting', 20601010.0),
#  ('Music;Music & Video', 20100000.0),
#  ('Adventure;Education', 20000000.0),
#  ('Card;Action & Adventure', 20000000.0),
#  ('Casual;Music & Video', 20000000.0),
#  ('Lifestyle;Pretend Play', 20000000.0),
#  ('Role Playing;Brain Games', 20000000.0),
#  ('Tools;Education', 20000000.0),
#  ('Education;Creativity', 16500000.0),
#  ('Events', 16073160.0),
#  ('Educational', 13669100.0),
#  ('Entertainment;Creativity', 13000000.0),
#  ('Educational;Creativity', 12000000.0),
#  ('Parenting;Music & Video', 11710000.0),
#  ('Entertainment;Pretend Play', 11000000.0),
#  ('Sports;Action & Adventure', 10200000.0),
#  ('Education;Pretend Play', 10000000.0),
#  ('Video Players & Editors;Creativity', 10000000.0),
#  ('Entertainment;Action & Adventure', 8000000.0),
#  ('Board;Action & Adventure', 7000000.0),
#  ('Education;Music & Video', 6200000.0),
#  ('Education;Action & Adventure', 4000000.0),
#  ('Board;Brain Games', 3850000.0),
#  ('Parenting;Education', 3180000.0),
#  ('Casual;Education', 3000000.0),
#  ('Arcade;Pretend Play', 2000000.0),
#  ('Entertainment;Education', 2000000.0),
#  ('Health & Fitness;Action & Adventure', 2000000.0),
#  ('Parenting;Brain Games', 2000000.0),
#  ('Puzzle;Creativity', 2000000.0),
#  ('Racing;Pretend Play', 2000000.0),
#  ('Strategy;Action & Adventure', 2000000.0),
#  ('Strategy;Creativity', 2000000.0),
#  ('Art & Design;Creativity', 1810000.0),
#  ('Simulation;Pretend Play', 1200000.0),
#  ('Art & Design;Pretend Play', 1000000.0),
#  ('Communication;Creativity', 1000000.0),
#  ('Music & Audio;Music & Video', 1000000.0),
#  ('Strategy;Education', 1000000.0),
#  ('Art & Design;Action & Adventure', 200000.0),
#  ('Health & Fitness;Education', 200000.0),
#  ('Lifestyle;Education', 200000.0),
#  ('Puzzle;Education', 200000.0),
#  ('Travel & Local;Action & Adventure', 200000.0),
#  ('Comics;Creativity', 100000.0),
#  ('Books & Reference;Education', 2000.0),
#  ('Simulation;Education', 1000.0),
#  ('Trivia;Education', 200.0)]

# %% [markdown]
# **Looks like Communication apps are the most downloaded and installed ones, if we consider the "genres" column. But since Android apps dataset has seemly 2 columns for genre (genre itself and category), we have to check the other column.**

# %%
android_category_installs = {}

for row in android_free:
    category = row[1]
    
    installs = row[5]
    installs = installs.replace('+','')
    installs = installs.replace(',','')
    installs = float(installs)
    
    if category not in android_category_installs:
        android_category_installs[category] = installs
        
    if category in android_category_installs:
        android_category_installs[category] += installs

# %%
sorted(android_category_installs.items(), key=lambda x: (-x[1], x[0]))
# Out:
# [('GAME', 13446919450.0),
#  ('COMMUNICATION', 12036906201.0),
#  ('TOOLS', 9101043474.0),
#  ('SOCIAL', 6487861902.0),
#  ('PRODUCTIVITY', 6291679314.0),
#  ('FAMILY', 6200925690.0),
#  ('VIDEO_PLAYERS', 4931731720.0),
#  ('PHOTOGRAPHY', 4657268815.0),
#  ('TRAVEL_AND_LOCAL', 2944704086.0),
#  ('NEWS_AND_MAGAZINES', 2378207260.0),
#  ('BOOKS_AND_REFERENCE', 1665985260.0),
#  ('PERSONALIZATION', 1579235988.0),
#  ('SHOPPING', 1410338585.0),
#  ('HEALTH_AND_FITNESS', 1144048402.0),
#  ('SPORTS', 1095330683.0),
#  ('ENTERTAINMENT', 990460000.0),
#  ('BUSINESS', 706952090.0),
#  ('MAPS_AND_NAVIGATION', 603160780.0),
#  ('LIFESTYLE', 507584429.0),
#  ('FINANCE', 465163132.0),
#  ('WEATHER', 410288520.0),
#  ('FOOD_AND_DRINK', 211788751.0),
#  ('EDUCATION', 188950000.0),
#  ('DATING', 150914757.0),
#  ('ART_AND_DESIGN', 118211100.0),
#  ('HOUSE_AND_HOME', 107202461.0),
#  ('AUTO_AND_VEHICLES', 53180061.0),
#  ('LIBRARIES_AND_DEMO', 53045810.0),
#  ('COMICS', 45471150.0),
#  ('MEDICAL', 38732344.0),
#  ('PARENTING', 31481010.0),
#  ('BEAUTY', 27697050.0),
#  ('EVENTS', 16073160.0)]

# %% [markdown]
# **Comparing the two dictionaries we have just created, the values on the main categories/genres are exactly the same. The only exception found was on "Games" category, which was not on "genres" column, but appeared as the largest volume on the two columns, a fact we can not ignore.**
#
# **So we decided to keep the values on category column, which were just equal genres column, but more complete.**

# %% [markdown]
# **Now Let's divide this by the number of apps by genre, and check the average download per genre**

# %%
android_freq_gen = freq_table(android_free, 1)
sorted(android_freq_gen.items(), key=lambda x: (-x[1], x[0]))
# Out:
# [('FAMILY', 1681),
#  ('GAME', 864),
#  ('TOOLS', 751),
#  ('BUSINESS', 409),
#  ('LIFESTYLE', 349),
#  ('PRODUCTIVITY', 347),
#  ('FINANCE', 329),
#  ('MEDICAL', 314),
#  ('SPORTS', 302),
#  ('PERSONALIZATION', 296),
#  ('COMMUNICATION', 288),
#  ('HEALTH_AND_FITNESS', 274),
#  ('PHOTOGRAPHY', 262),
#  ('NEWS_AND_MAGAZINES', 251),
#  ('SOCIAL', 237),
#  ('TRAVEL_AND_LOCAL', 208),
#  ('SHOPPING', 200),
#  ('BOOKS_AND_REFERENCE', 193),
#  ('DATING', 166),
#  ('VIDEO_PLAYERS', 160),
#  ('MAPS_AND_NAVIGATION', 126),
#  ('FOOD_AND_DRINK', 111),
#  ('EDUCATION', 104),
#  ('ENTERTAINMENT', 86),
#  ('LIBRARIES_AND_DEMO', 84),
#  ('AUTO_AND_VEHICLES', 83),
#  ('HOUSE_AND_HOME', 74),
#  ('WEATHER', 72),
#  ('EVENTS', 64),
#  ('PARENTING', 59),
#  ('ART_AND_DESIGN', 57),
#  ('COMICS', 56),
#  ('BEAUTY', 54)]

# %%
avg_inst_gen = {k:v1/android_freq_gen.get(k,0) for k,v1 in android_category_installs.items()}

# %%
sorted(avg_inst_gen.items(), key=lambda x: (-x[1], x[0]))
# Out:
# [('COMMUNICATION', 41794813.197916664),
#  ('VIDEO_PLAYERS', 30823323.25),
#  ('SOCIAL', 27374944.734177217),
#  ('PRODUCTIVITY', 18131640.674351584),
#  ('PHOTOGRAPHY', 17775835.171755724),
#  ('GAME', 15563564.17824074),
#  ('TRAVEL_AND_LOCAL', 14157231.182692308),
#  ('TOOLS', 12118566.543275632),
#  ('ENTERTAINMENT', 11516976.744186046),
#  ('NEWS_AND_MAGAZINES', 9474929.322709164),
#  ('BOOKS_AND_REFERENCE', 8632047.979274612),
#  ('SHOPPING', 7051692.925),
#  ('WEATHER', 5698451.666666667),
#  ('PERSONALIZATION', 5335256.716216216),
#  ('MAPS_AND_NAVIGATION', 4786990.317460317),
#  ('HEALTH_AND_FITNESS', 4175359.131386861),
#  ('FAMILY', 3688831.463414634),
#  ('SPORTS', 3626922.7913907287),
#  ('ART_AND_DESIGN', 2073878.9473684211),
#  ('FOOD_AND_DRINK', 1908006.7657657657),
#  ('EDUCATION', 1816826.923076923),
#  ('BUSINESS', 1728489.2176039119),
#  ('LIFESTYLE', 1454396.6446991405),
#  ('HOUSE_AND_HOME', 1448681.9054054054),
#  ('FINANCE', 1413869.7021276595),
#  ('DATING', 909125.0421686746),
#  ('COMICS', 811984.8214285715),
#  ('AUTO_AND_VEHICLES', 640723.626506024),
#  ('LIBRARIES_AND_DEMO', 631497.7380952381),
#  ('PARENTING', 533576.4406779661),
#  ('BEAUTY', 512908.3333333333),
#  ('EVENTS', 251143.125),
#  ('MEDICAL', 123351.41401273885)]

# %% [markdown]
# **As we can see, Android apps set is dominated by gaming and communication apps. Let's know further the top apps on the top genres, starting with the "Communication" ones.**

# %%
communication_apps = []

for row in android_free:
    genre = row[1]
    if genre == 'COMMUNICATION':
        communication_apps.append(row)

# %%
sorted (communication_apps)
# Out:
# [['/u/app',
#   'COMMUNICATION',
#   '4.7',
#   '573',
#   '53M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'July 3, 2018',
#   '4.2.4',
#   '4.1 and up'],
#  ['2ndLine - Second Phone Number',
#   'COMMUNICATION',
#   '4.2',
#   '15880',
#   '32M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   '5.65.0',
#   '4.0 and up'],
#  ['3G DZ Configuration',
#   'COMMUNICATION',
#   '4.3',
#   '488',
#   '2.5M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 19, 2015',
#   '6.2.3',
#   '3.0 and up'],
#  ['AC-BL',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '4.3M',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 20, 2018',
#   '1.7',
#   '2.1 and up'],
#  ['AG Contacts, Lite edition',
#   'COMMUNICATION',
#   '4.5',
#   '185',
#   '3.7M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 18, 2018',
#   '8.05.18.14250',
#   '4.0.3 and up'],
#  ['AK Phone',
#   'COMMUNICATION',
#   '4.4',
#   '9',
#   '4.2M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 29, 2017',
#   '3.8.8',
#   '2.2 and up'],
#  ['AT&T Call Protect',
#   'COMMUNICATION',
#   '4.2',
#   '6454',
#   '15M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 3, 2018',
#   '1.5.13-3598',
#   '5.0 and up'],
#  ['AT&T Messages for Tablet',
#   'COMMUNICATION',
#   '3.3',
#   '3044',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 3, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['AT&T Visual Voicemail',
#   'COMMUNICATION',
#   '3.7',
#   '13761',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['ATC Unico BS',
#   'COMMUNICATION',
#   'NaN',
#   '10',
#   '5.3M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 16, 2015',
#   '0.12',
#   '4.1 and up'],
#  ['AU Call Blocker - Block Unwanted Calls Texts 2018',
#   'COMMUNICATION',
#   '4.2',
#   '16',
#   '3.3M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 24, 2018',
#   '1.0.4',
#   '4.1 and up'],
#  ['AV Phone',
#   'COMMUNICATION',
#   'NaN',
#   '4',
#   '3.7M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 9, 2018',
#   '2.1.9',
#   '5.1 and up'],
#  ['AW - free video calls and chat',
#   'COMMUNICATION',
#   '4.0',
#   '7317',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'July 4, 2018',
#   '1.0.08.73',
#   '4.0.3 and up'],
#  ['AZ Browser. Private & Download',
#   'COMMUNICATION',
#   '4.4',
#   '1520',
#   '5.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 31, 2016',
#   '1.4',
#   '4.4 and up'],
#  ['Access Point Names',
#   'COMMUNICATION',
#   '4.0',
#   '138',
#   '2.4M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 12, 2014',
#   '1.0',
#   '2.3.3 and up'],
#  ['Ad Blocker Turbo - Adblocker Browser',
#   'COMMUNICATION',
#   '3.9',
#   '107',
#   '44M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 29, 2018',
#   '1.0.5',
#   '4.1 and up'],
#  ['Adblock Browser for Android',
#   'COMMUNICATION',
#   '4.1',
#   '121113',
#   '39M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 11, 2018',
#   '1.4.0',
#   '4.1 and up'],
#  ['Adblock Plus for Samsung Internet - Browse safe.',
#   'COMMUNICATION',
#   '4.0',
#   '8769',
#   '2.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 5, 2018',
#   '1.1.4',
#   '5.0 and up'],
#  ['Aj.Petra',
#   'COMMUNICATION',
#   'NaN',
#   '5',
#   '14M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 29, 2017',
#   '1.0.1',
#   '4.1 and up'],
#  ['All Email Providers',
#   'COMMUNICATION',
#   '4.1',
#   '20901',
#   '7.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 3, 2018',
#   '5.0.9',
#   '4.1 and up'],
#  ['Amadeus GR & CY',
#   'COMMUNICATION',
#   'NaN',
#   '4',
#   '3.8M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 1, 2018',
#   '2.07',
#   '4.1 and up'],
#  ['Android Messages',
#   'COMMUNICATION',
#   '4.2',
#   '781810',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['AntennaPict β',
#   'COMMUNICATION',
#   '4.3',
#   '15439',
#   '2.2M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 7, 2016',
#   '2.0.0',
#   '2.3 and up'],
#  ['Antillean Gold Telegram (original version)',
#   'COMMUNICATION',
#   '4.4',
#   '2939',
#   '17M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 16, 2018',
#   '2.1',
#   '4.1 and up'],
#  ['AudioBT: BT audio GPS/SMS/Text',
#   'COMMUNICATION',
#   '3.4',
#   '198',
#   '219k',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 21, 2017',
#   '3.2.1',
#   '4.0 and up'],
#  ['Azar',
#   'COMMUNICATION',
#   '4.2',
#   '1092337',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'July 24, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['BA SALES',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '2.9M',
#   '1+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 31, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['BBM - Free Calls & Messages',
#   'COMMUNICATION',
#   '4.3',
#   '12843436',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 2, 2018',
#   'Varies with device',
#   '4.0.3 and up'],
#  ['BBMoji - Your personalized BBM Stickers',
#   'COMMUNICATION',
#   '4.3',
#   '8827',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 22, 2018',
#   '1.0.2',
#   '4.0.3 and up'],
#  ['BD Data Plan (3G & 4G)',
#   'COMMUNICATION',
#   '4.4',
#   '10341',
#   '6.9M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 5, 2018',
#   '5.2.4',
#   '4.1 and up'],
#  ['BD Dialer',
#   'COMMUNICATION',
#   '4.1',
#   '29',
#   '13M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 9, 2018',
#   '1.8.3',
#   '4.1 and up'],
#  ['BD Internet Packages (Updated)',
#   'COMMUNICATION',
#   '4.0',
#   '474',
#   '3.0M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 5, 2016',
#   '0.0.5',
#   '4.0 and up'],
#  ['BD Live Call',
#   'COMMUNICATION',
#   '4.4',
#   '7',
#   '308k',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 6, 2016',
#   '1.01',
#   '2.0 and up'],
#  ['BF Browser by Betfilter - Stop Gambling Today!',
#   'COMMUNICATION',
#   '3.0',
#   '39',
#   '4.6M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 4, 2017',
#   '1.4',
#   '4.0.3 and up'],
#  ['BH Mail',
#   'COMMUNICATION',
#   '3.4',
#   '7',
#   '6.0M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 3, 2018',
#   '5.403',
#   '4.0.3 and up'],
#  ['BJ - Confidential',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '3.2M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'April 23, 2018',
#   '1.7',
#   '4.1 and up'],
#  ['BK Chat',
#   'COMMUNICATION',
#   'NaN',
#   '6',
#   '31M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'July 30, 2018',
#   '2.1',
#   '4.1 and up'],
#  ['BN MALLORCA Radio',
#   'COMMUNICATION',
#   'NaN',
#   '23',
#   '13M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 29, 2017',
#   '2.0.14.4',
#   '2.3 and up'],
#  ['BQ Partners',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   'Varies with device',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['BS-Mobile',
#   'COMMUNICATION',
#   '5.0',
#   '1',
#   '683k',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 3, 2015',
#   '0.1',
#   '2.3 and up'],
#  ['BT MeetMe with Dolby Voice',
#   'COMMUNICATION',
#   '3.6',
#   '437',
#   '12M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 13, 2018',
#   '2.66.5',
#   '5.0 and up'],
#  ['BT Messenger',
#   'COMMUNICATION',
#   '3.9',
#   '97',
#   '598k',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 15, 2015',
#   '1.0',
#   '2.2 and up'],
#  ['BT One Phone Mobile App',
#   'COMMUNICATION',
#   '3.5',
#   '33',
#   '2.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 18, 2017',
#   '2.2.6',
#   '4.1 and up'],
#  ['BT One Voice mobile access',
#   'COMMUNICATION',
#   '4.0',
#   '32',
#   '437k',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 30, 2015',
#   'Version 1.6',
#   '1.6 and up'],
#  ['BV',
#   'COMMUNICATION',
#   '5.0',
#   '3',
#   '1.6M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 4, 2016',
#   '1,01',
#   '3.0 and up'],
#  ['Baby Monitor AV',
#   'COMMUNICATION',
#   '3.3',
#   '1434',
#   '9.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 6, 2014',
#   '1.2.5',
#   '2.3 and up'],
#  ["Bee'ah Employee App",
#   'COMMUNICATION',
#   '4.0',
#   '4',
#   '5.4M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'December 24, 2017',
#   '2.26.5.0',
#   '5.0 and up'],
#  ['Best Auto Call Recorder Free',
#   'COMMUNICATION',
#   '3.7',
#   '7',
#   '4.3M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 2, 2017',
#   '2.1',
#   '4.1 and up'],
#  ['Best Browser BD social networking',
#   'COMMUNICATION',
#   '4.8',
#   '6',
#   '21M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 4, 2018',
#   '2.0',
#   '4.1 and up'],
#  ['BlueDV AMBE',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   'Varies with device',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Bluetooth Auto Connect',
#   'COMMUNICATION',
#   '3.9',
#   '20829',
#   '1.9M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 17, 2017',
#   '4.5.4',
#   '3.0 and up'],
#  ['Brave Browser: Fast AdBlocker',
#   'COMMUNICATION',
#   '4.3',
#   '40241',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 30, 2018',
#   '1.0.52',
#   '4.1 and up'],
#  ['Browser 4G',
#   'COMMUNICATION',
#   '4.3',
#   '192948',
#   '6.6M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 19, 2018',
#   '24.6.6',
#   '4.0.3 - 7.1.1'],
#  ['Burner - Free Phone Number',
#   'COMMUNICATION',
#   '4.3',
#   '14873',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 12, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['C W Browser',
#   'COMMUNICATION',
#   '4.4',
#   '14',
#   '17M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 28, 2017',
#   '1.0',
#   '4.0 and up'],
#  ['CB On Mobile',
#   'COMMUNICATION',
#   '4.1',
#   '901',
#   '323k',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'April 26, 2017',
#   '1.0.5',
#   '4.0 and up'],
#  ['CB Radio Chat - for friends!',
#   'COMMUNICATION',
#   '4.0',
#   '17998',
#   '7.9M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'March 27, 2018',
#   '2.6.3',
#   '4.0 and up'],
#  ['CF Chat: Connecting Friends',
#   'COMMUNICATION',
#   '3.4',
#   '5',
#   '2.4M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'April 27, 2016',
#   '1.4',
#   '2.3 and up'],
#  ['CIA - Caller ID & Call Blocker',
#   'COMMUNICATION',
#   '4.0',
#   '60308',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 22, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['CJ Browser - Fast & Private',
#   'COMMUNICATION',
#   '4.2',
#   '5',
#   '15M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 7, 2017',
#   '1.0',
#   '4.0 and up'],
#  ['CJ DVD Rentals',
#   'COMMUNICATION',
#   '1.0',
#   '5',
#   '13M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 6, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['CK Call NEW',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '4.2M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 26, 2017',
#   '3.8.8',
#   '2.2 and up'],
#  ['CM Browser - Ad Blocker , Fast Download , Privacy',
#   'COMMUNICATION',
#   '4.6',
#   '2265084',
#   '6.1M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   '5.22.18.0006',
#   '4.0 and up'],
#  ['CM Transfer - Share any files with friends nearby',
#   'COMMUNICATION',
#   '4.6',
#   '71740',
#   '5.8M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 27, 2018',
#   '2.0.7.0014',
#   '4.0 and up'],
#  ['CQ-Alert',
#   'COMMUNICATION',
#   'NaN',
#   '3',
#   '8.1M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 28, 2016',
#   '5.5.0',
#   '4.0 and up'],
#  ['CQ-Mobile',
#   'COMMUNICATION',
#   'NaN',
#   '10',
#   '8.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 28, 2016',
#   '5.5.0',
#   '4.0 and up'],
#  ['CS Browser Beta',
#   'COMMUNICATION',
#   '4.3',
#   '125',
#   '53M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 16, 2017',
#   '60.0.3112.3046279',
#   '4.1 and up'],
#  ['CS Browser | #1 & BEST BROWSER',
#   'COMMUNICATION',
#   '3.8',
#   '52',
#   '2.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 28, 2015',
#   '2.0',
#   '3.0 and up'],
#  ['CS Customizer',
#   'COMMUNICATION',
#   '3.7',
#   '25',
#   '3.7M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 6, 2017',
#   '1.2.11',
#   '3.0 and up'],
#  ['CW BLE Peripheral Simulator',
#   'COMMUNICATION',
#   'NaN',
#   '2',
#   '1.5M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 8, 2017',
#   '1.0',
#   '4.4 and up'],
#  ['CW Bluetooth SPP',
#   'COMMUNICATION',
#   'NaN',
#   '3',
#   '961k',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 31, 2018',
#   '1.2',
#   '6.0 and up'],
#  ['Call Blocker & Blacklist',
#   'COMMUNICATION',
#   '4.0',
#   '6',
#   '4.2M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 13, 2018',
#   '3.1.0',
#   '4.0 and up'],
#  ['Call Blocker - Blacklist, SMS Blocker',
#   'COMMUNICATION',
#   '4.2',
#   '30350',
#   '3.7M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 16, 2018',
#   '10.0.0',
#   '4.1 and up'],
#  ['Call Control - Call Blocker',
#   'COMMUNICATION',
#   '4.4',
#   '93825',
#   '11M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 5, 2018',
#   '2.17.3',
#   '4.1 and up'],
#  ['Call Free – Free Call',
#   'COMMUNICATION',
#   '4.3',
#   '30209',
#   '15M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 28, 2018',
#   '1.3.4',
#   '4.1 and up'],
#  ['CallApp: Caller ID, Blocker & Phone Call Recorder',
#   'COMMUNICATION',
#   '4.4',
#   '483782',
#   '20M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 29, 2018',
#   '1.286',
#   '4.1 and up'],
#  ['Caller ID & Call Block - DU Caller',
#   'COMMUNICATION',
#   '4.6',
#   '93930',
#   '14M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   '4.0.8',
#   '4.2 and up'],
#  ['Caller ID +',
#   'COMMUNICATION',
#   '4.0',
#   '9498',
#   '118k',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 7, 2016',
#   '5.28.0',
#   '2.3 and up'],
#  ['Calls & Text by Mo+',
#   'COMMUNICATION',
#   '4.2',
#   '83239',
#   '14M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 19, 2018',
#   '3.0.4',
#   '4.0 and up'],
#  ['Calls Blacklist - Call Blocker',
#   'COMMUNICATION',
#   '4.5',
#   '457283',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 24, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Carpooling FH Hagenberg',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   'Varies with device',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 18, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Cb browser',
#   'COMMUNICATION',
#   '5.0',
#   '5',
#   '3.7M',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 2, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['Channel 19',
#   'COMMUNICATION',
#   '3.7',
#   '916',
#   '12M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'July 13, 2018',
#   '2.2.6',
#   '4.1 and up'],
#  ['Chrome Dev',
#   'COMMUNICATION',
#   '4.4',
#   '63576',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 2, 2018',
#   '69.0.3497.24',
#   'Varies with device'],
#  ['ClanHQ',
#   'COMMUNICATION',
#   '2.7',
#   '560',
#   '37M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 25, 2018',
#   '1.0.21',
#   '4.4 and up'],
#  ['ClanPlay: Community and Tools for Gamers',
#   'COMMUNICATION',
#   '4.8',
#   '34443',
#   '27M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'June 28, 2018',
#   '1.14.3',
#   '5.0 and up'],
#  ['Contacts',
#   'COMMUNICATION',
#   '4.3',
#   '66602',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 26, 2018',
#   '2.8.4.201036949',
#   '5.0 and up'],
#  ['Contacts+',
#   'COMMUNICATION',
#   '4.2',
#   '190613',
#   '11M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   '5.85.1',
#   '4.0.3 and up'],
#  ['Council Voting Calculator',
#   'COMMUNICATION',
#   '3.9',
#   '33',
#   '3.4M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 6, 2017',
#   '2.3.0',
#   '4.1 and up'],
#  ['Cricket Visual Voicemail',
#   'COMMUNICATION',
#   '3.9',
#   '13698',
#   '5.1M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 2, 2018',
#   '3.2.0.100171',
#   '4.1 and up'],
#  ['Cy Messenger',
#   'COMMUNICATION',
#   '4.5',
#   '4',
#   '8.1M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 30, 2014',
#   '1.3.0',
#   '2.3.3 and up'],
#  ['DG Card',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   'Varies with device',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 15, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['DK Browser',
#   'COMMUNICATION',
#   '4.0',
#   '1',
#   '2.4M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 25, 2017',
#   '1.0',
#   '4.2 and up'],
#  ['DK TEL Dialer',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '4.2M',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 26, 2017',
#   '3.8.8',
#   '2.2 and up'],
#  ['DM - The Offical Messaging App',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '11M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'December 20, 2017',
#   '1.3',
#   '4.0.3 and up'],
#  ['DM Talk New',
#   'COMMUNICATION',
#   'NaN',
#   '3',
#   '4.2M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 7, 2018',
#   '3.8.8',
#   '2.2 and up'],
#  ['DM Tracker',
#   'COMMUNICATION',
#   '3.5',
#   '11',
#   '5.2M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   '2.0.1',
#   '4.3 and up'],
#  ['DM for WhatsApp',
#   'COMMUNICATION',
#   '4.4',
#   '25',
#   '2.9M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 3, 2018',
#   '0.3.7',
#   '4.4 and up'],
#  ['DMR BrandMeister Tool',
#   'COMMUNICATION',
#   '3.3',
#   '78',
#   '2.5M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 31, 2018',
#   '4.5',
#   '6.0 and up'],
#  ['DU Browser—Browse fast & fun',
#   'COMMUNICATION',
#   '4.3',
#   '1133539',
#   '4.7M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 1, 2016',
#   '6.4.0.4',
#   '4.0 and up'],
#  ['DW Contacts & Phone & Dialer',
#   'COMMUNICATION',
#   '4.3',
#   '21186',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Daum Mail - Next Mail',
#   'COMMUNICATION',
#   '4.3',
#   '41420',
#   '19M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 21, 2018',
#   '3.2.0',
#   '4.0 and up'],
#  ['Deaf World DW',
#   'COMMUNICATION',
#   '4.3',
#   '298',
#   'Varies with device',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'November 28, 2017',
#   'Varies with device',
#   '4.1 and up'],
#  ['Discord - Chat for Gamers',
#   'COMMUNICATION',
#   '4.5',
#   '305347',
#   '39M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'July 27, 2018',
#   '7.1.8',
#   '4.1 and up'],
#  ['Dolphin Browser - Fast, Private & Adblock🐬',
#   'COMMUNICATION',
#   '4.5',
#   '2511130',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['EHiN-FH conferenceapp',
#   'COMMUNICATION',
#   'NaN',
#   '5',
#   '26M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 15, 2016',
#   '1.17',
#   '4.1 and up'],
#  ['EJ messenger',
#   'COMMUNICATION',
#   '5.0',
#   '1',
#   '25M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'October 18, 2017',
#   '1.0',
#   '4.0 and up'],
#  ['EO Mumbai',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '11M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 21, 2018',
#   '1.02',
#   '4.1 and up'],
#  ['EP RSS Reader',
#   'COMMUNICATION',
#   '3.8',
#   '4',
#   '892k',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 16, 2018',
#   '0.99',
#   '4.0.3 and up'],
#  ['ES-1',
#   'COMMUNICATION',
#   'NaN',
#   '6',
#   '2.7M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 5, 2016',
#   '1.0',
#   '1.6 and up'],
#  ['EU Council',
#   'COMMUNICATION',
#   'NaN',
#   '7',
#   '19M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 4, 2018',
#   '1.3.0',
#   '4.4 and up'],
#  ['EZ Wifi Notification',
#   'COMMUNICATION',
#   '4.3',
#   '260',
#   '193k',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 11, 2014',
#   '1.8',
#   '2.2 and up'],
#  ['Ear Agent: Super Hearing',
#   'COMMUNICATION',
#   '3.7',
#   '42329',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Eg Call',
#   'COMMUNICATION',
#   '4.2',
#   '91',
#   '6.0M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 26, 2017',
#   '3.8.6',
#   '2.2 and up'],
#  ['Ek IRA',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '5.7M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 27, 2018',
#   '0.3.1',
#   '4.1 and up'],
#  ['Email TypeApp - Mail App',
#   'COMMUNICATION',
#   '4.6',
#   '183374',
#   '44M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   '1.9.4.74',
#   '4.1 and up'],
#  ['Everbridge',
#   'COMMUNICATION',
#   '3.1',
#   '497',
#   '36M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 17, 2018',
#   '8.6.2',
#   '4.4 and up'],
#  ['ExDialer - Dialer & Contacts',
#   'COMMUNICATION',
#   '4.2',
#   '125232',
#   '2.7M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 5, 2017',
#   '196',
#   '2.1 and up'],
#  ['FC Browser - Focus Privacy Browser',
#   'COMMUNICATION',
#   '4.1',
#   '26',
#   '4.6M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 24, 2017',
#   '1.0',
#   '5.0 and up'],
#  ['FN Web Radio',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '1.6M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 18, 2018',
#   '1.1',
#   '2.3 and up'],
#  ['FNH Payment Info',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '2.1M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 17, 2018',
#   '1.3',
#   '4.0.3 and up'],
#  ['FO AIRBUS Nantes',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '17M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 14, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['FO AIRBUS TLSE',
#   'COMMUNICATION',
#   'NaN',
#   '4',
#   '16M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 25, 2018',
#   '1.1',
#   '4.1 and up'],
#  ['FO Interim',
#   'COMMUNICATION',
#   'NaN',
#   '1',
#   '11M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 14, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['FO OP St-Nazaire',
#   'COMMUNICATION',
#   'NaN',
#   '1',
#   '17M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 19, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['FO PSA Sept-Fons',
#   'COMMUNICATION',
#   'NaN',
#   '2',
#   '15M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 22, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['FO RCBT',
#   'COMMUNICATION',
#   'NaN',
#   '5',
#   '15M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 15, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['FO SODEXO',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '16M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 13, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['FO STELIA Méaulte',
#   'COMMUNICATION',
#   'NaN',
#   '2',
#   '18M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 19, 2017',
#   '1.1',
#   '4.1 and up'],
#  ['FP Connect',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '22M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'December 15, 2017',
#   '3.15.1',
#   '4.1 and up'],
#  ['FP Live',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '3.3M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'November 3, 2017',
#   '1.2.4',
#   '4.2 and up'],
#  ['Feel Performer',
#   'COMMUNICATION',
#   '2.2',
#   '62',
#   '34M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 9, 2018',
#   '2.0.3',
#   '4.1 and up'],
#  ['Firefox Browser fast & private',
#   'COMMUNICATION',
#   '4.4',
#   '3075118',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 10, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Firefox Focus: The privacy browser',
#   'COMMUNICATION',
#   '4.4',
#   '36981',
#   '4.0M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 6, 2018',
#   '5.2',
#   '5.0 and up'],
#  ['Free Adblocker Browser - Adblock & Popup Blocker',
#   'COMMUNICATION',
#   '4.4',
#   '152470',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 19, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Free Wi-fi HotspoT',
#   'COMMUNICATION',
#   '4.1',
#   '382',
#   '2.3M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 20, 2018',
#   '2.5',
#   '4.0 and up'],
#  ['Free WiFi Connect',
#   'COMMUNICATION',
#   '3.9',
#   '167229',
#   '9.7M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 31, 2018',
#   '8.1',
#   '4.1 and up'],
#  ['FreedomPop Messaging Phone/SIM',
#   'COMMUNICATION',
#   '3.6',
#   '9894',
#   '39M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   '23.01.1265.0712',
#   '4.1 and up'],
#  ['Full Screen Caller ID',
#   'COMMUNICATION',
#   '4.2',
#   '104990',
#   '10M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 15, 2018',
#   '3.5.0',
#   '4.0.3 and up'],
#  ['GMX Mail',
#   'COMMUNICATION',
#   '4.3',
#   '258556',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['GO Notifier',
#   'COMMUNICATION',
#   '4.2',
#   '124346',
#   '695k',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 6, 2014',
#   '2.8',
#   '2.0 and up'],
#  ['GO SMS Pro - Messenger, Free Themes, Emoji',
#   'COMMUNICATION',
#   '4.4',
#   '2876500',
#   '24M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   '7.73',
#   '4.0 and up'],
#  ['Ghostery Privacy Browser',
#   'COMMUNICATION',
#   '4.1',
#   '13100',
#   '2.2M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 20, 2018',
#   '1.4.1.0',
#   '4.0.3 and up'],
#  ['Glide - Video Chat Messenger',
#   'COMMUNICATION',
#   '4.3',
#   '350154',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 29, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Gmail',
#   'COMMUNICATION',
#   '4.3',
#   '4604483',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Goodbox - Mega App',
#   'COMMUNICATION',
#   '4.3',
#   '3429',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 8, 2018',
#   '1.10.279.2',
#   '4.2 and up'],
#  ['Google Allo',
#   'COMMUNICATION',
#   '4.3',
#   '347086',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 23, 2018',
#   'Varies with device',
#   '4.1 and up'],
#  ['Google Chrome: Fast & Secure',
#   'COMMUNICATION',
#   '4.3',
#   '9643041',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Google Duo - High Quality Video Calls',
#   'COMMUNICATION',
#   '4.6',
#   '2083237',
#   'Varies with device',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   '37.1.206017801.DR37_RC14',
#   '4.4 and up'],
#  ['Google Voice',
#   'COMMUNICATION',
#   '4.2',
#   '171052',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['GroupMe',
#   'COMMUNICATION',
#   '4.5',
#   '330761',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Ham DX Cluster & Spots Finder',
#   'COMMUNICATION',
#   '4.5',
#   '115',
#   '2.8M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 15, 2016',
#   '1.4.4',
#   '4.1 and up'],
#  ['Ham Radio Prefixes',
#   'COMMUNICATION',
#   '3.7',
#   '218',
#   '3.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 12, 2014',
#   '1.12',
#   '2.3 and up'],
#  ['Hangouts',
#   'COMMUNICATION',
#   '4.0',
#   '3419513',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 21, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Hangouts Dialer - Call Phones',
#   'COMMUNICATION',
#   '4.0',
#   '122512',
#   '79k',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 2, 2015',
#   '0.1.100944346',
#   '4.0.3 and up'],
#  ['Have your say on Europe',
#   'COMMUNICATION',
#   '3.8',
#   '19',
#   '21M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 19, 2018',
#   '1.1.0',
#   '4.1 and up'],
#  ['HipChat - beta version',
#   'COMMUNICATION',
#   '4.1',
#   '1035',
#   '20M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 7, 2018',
#   '3.20.001',
#   '4.1 and up'],
#  ['Hiya - Caller ID & Block',
#   'COMMUNICATION',
#   '4.4',
#   '177703',
#   '13M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'July 25, 2018',
#   '8.1.2-6310',
#   '5.0 and up'],
#  ['Hlášenírozhlasu.cz',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '17M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 27, 2018',
#   '2.1.3',
#   '4.1 and up'],
#  ['Hyundai CX Conference',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '20M',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 27, 2018',
#   '2.10.2',
#   '4.2 and up'],
#  ['ICQ — Video Calls & Chat Messenger',
#   'COMMUNICATION',
#   '4.4',
#   '697939',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 18, 2018',
#   '7.3(823181)',
#   '4.4 and up'],
#  ['IZ2UUF Morse Koch CW',
#   'COMMUNICATION',
#   '4.6',
#   '649',
#   '837k',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 8, 2013',
#   '1.0.013',
#   '2.1 and up'],
#  ['InBrowser - Incognito Browsing',
#   'COMMUNICATION',
#   '4.2',
#   '27156',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Inbox.eu',
#   'COMMUNICATION',
#   '3.7',
#   '98',
#   '9.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 11, 2018',
#   '6.4.7',
#   '4.3 and up'],
#  ['Jazz Wi-Fi',
#   'COMMUNICATION',
#   '3.4',
#   '49',
#   '4.0M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 10, 2017',
#   '0.1',
#   '2.3 and up'],
#  ['JusTalk - Free Video Calls and Fun Video Chat',
#   'COMMUNICATION',
#   '4.6',
#   '191032',
#   '26M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 4, 2018',
#   '7.2.29',
#   '4.0.3 and up'],
#  ['K-9 Mail',
#   'COMMUNICATION',
#   '4.2',
#   '88427',
#   '5.1M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 6, 2018',
#   '5.403',
#   '4.0.3 and up'],
#  ['K-9 Material (unofficial)',
#   'COMMUNICATION',
#   '4.4',
#   '64',
#   '4.5M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'March 27, 2017',
#   '5.206',
#   '5.0 and up'],
#  ['K-@ Mail - Email App',
#   'COMMUNICATION',
#   '4.1',
#   '1760',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 23, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['KakaoTalk: Free Calls & Text',
#   'COMMUNICATION',
#   '4.3',
#   '2546549',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Katalogen.ax',
#   'COMMUNICATION',
#   'NaN',
#   '1',
#   '172k',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 2, 2014',
#   '1.0.0',
#   '2.2 and up'],
#  ['Kik',
#   'COMMUNICATION',
#   '4.3',
#   '2451136',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['LINE: Free Calls & Messages',
#   'COMMUNICATION',
#   '4.2',
#   '10790289',
#   'Varies with device',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Learn Morse Code - G0HYN Learn Morse',
#   'COMMUNICATION',
#   '4.0',
#   '27',
#   '600k',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 8, 2018',
#   '5.0',
#   '2.2 and up'],
#  ['Lightning Web Browser',
#   'COMMUNICATION',
#   '4.1',
#   '12578',
#   '2.3M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 10, 2017',
#   '4.5.1',
#   '4.0 and up'],
#  ['Lite for Facebook Messenger',
#   'COMMUNICATION',
#   '4.3',
#   '76498',
#   '4.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'June 20, 2018',
#   '6.3.2',
#   'Varies with device'],
#  ['LokLok: Draw on a Lock Screen',
#   'COMMUNICATION',
#   '4.1',
#   '14766',
#   '16M',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'September 20, 2017',
#   '0.81 beta',
#   '4.0.3 and up'],
#  ['M star Dialer',
#   'COMMUNICATION',
#   '3.5',
#   '400',
#   '4.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 20, 2017',
#   '3.8.8',
#   '2.2 and up'],
#  ['MARKET FO',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '15M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 30, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['Mail.Ru - Email App',
#   'COMMUNICATION',
#   '4.6',
#   '837842',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Mail1Click - Secure Mail',
#   'COMMUNICATION',
#   '4.1',
#   '255',
#   '1.6M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 11, 2017',
#   '2.3',
#   '2.2 and up'],
#  ['MegaFon Dashboard',
#   'COMMUNICATION',
#   '3.7',
#   '99559',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Messaging+ SMS, MMS Free',
#   'COMMUNICATION',
#   '4.1',
#   '28238',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 2, 2018',
#   '4.98',
#   '2.3 and up'],
#  ['Messenger Lite: Free Calls & Messages',
#   'COMMUNICATION',
#   '4.4',
#   '1429038',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 25, 2018',
#   '37.0.0.7.163',
#   '2.3 and up'],
#  ['Messenger for SMS',
#   'COMMUNICATION',
#   '4.3',
#   '125257',
#   '17M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'June 6, 2018',
#   '1.8.9',
#   '4.1 and up'],
#  ['Messenger – Text and Video Chat for Free',
#   'COMMUNICATION',
#   '4.0',
#   '56646578',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Microsoft Edge',
#   'COMMUNICATION',
#   '4.3',
#   '27187',
#   '66M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 28, 2018',
#   '42.0.0.2059',
#   '4.4 and up'],
#  ['Mircules DX Cluster Lite',
#   'COMMUNICATION',
#   '4.5',
#   '51',
#   '21M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 10, 2016',
#   '3.0',
#   '4.1 and up'],
#  ['Morse Code Reader',
#   'COMMUNICATION',
#   '3.9',
#   '1436',
#   '20k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 26, 2013',
#   '1.0',
#   '1.6 and up'],
#  ['Mr. Number-Block calls & spam',
#   'COMMUNICATION',
#   '4.2',
#   '177263',
#   '13M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'July 13, 2018',
#   '5.1.2-6310',
#   '5.0 and up'],
#  ['My BF App',
#   'COMMUNICATION',
#   '4.1',
#   '141',
#   '9.9M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 19, 2017',
#   '2.0',
#   '4.0 and up'],
#  ['My Tele2',
#   'COMMUNICATION',
#   '4.3',
#   '158679',
#   '8.8M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   '2.4.1',
#   '4.4 and up'],
#  ['My Vodacom SA',
#   'COMMUNICATION',
#   '3.7',
#   '25021',
#   '61M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 26, 2018',
#   '9.9.0',
#   '4.3 and up'],
#  ['My Vodafone (GR)',
#   'COMMUNICATION',
#   '3.8',
#   '12667',
#   '34M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   '4.5.5.1-2090AL-REL',
#   '4.3 and up'],
#  ['My magenta',
#   'COMMUNICATION',
#   '3.9',
#   '42370',
#   '37M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 25, 2018',
#   '7.5.1',
#   '5.0 and up'],
#  ['N-Com Wizard',
#   'COMMUNICATION',
#   '3.3',
#   '960',
#   '3.8M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 21, 2017',
#   '2.1.2',
#   '2.3.3 and up'],
#  ['Newton Mail - Email App for Gmail, Outlook, IMAP',
#   'COMMUNICATION',
#   '4.0',
#   '122595',
#   '30M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 19, 2018',
#   '9.8.376',
#   '5.0 and up'],
#  ['Ninesky Browser',
#   'COMMUNICATION',
#   '4.2',
#   '42925',
#   '2.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 27, 2017',
#   '6.1',
#   '2.3 and up'],
#  ['Of the wall Arapaho bk',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '12M',
#   '5+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 18, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['Oklahoma Ag Co-op Council',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '4.9M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 23, 2018',
#   '2.2.3',
#   '4.0.3 and up'],
#  ['Omlet Chat',
#   'COMMUNICATION',
#   '3.9',
#   '40751',
#   '35M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'November 4, 2016',
#   '2.2.7600',
#   '4.0.3 and up'],
#  ['Opera Browser: Fast and Secure',
#   'COMMUNICATION',
#   '4.4',
#   '2473795',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   '47.1.2249.129326',
#   'Varies with device'],
#  ['Opera Mini - fast web browser',
#   'COMMUNICATION',
#   '4.5',
#   '5150801',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 19, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Opera Mini browser beta',
#   'COMMUNICATION',
#   '4.4',
#   '401530',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Orfox: Tor Browser for Android',
#   'COMMUNICATION',
#   '4.2',
#   '44233',
#   '31M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 2, 2018',
#   'Fennec-52.9.0esr/TorBrowser-7.5-1/Orfox-1.5.4-RC-1',
#   '4.0.3 and up'],
#  ['PHONE for Google Voice & GTalk',
#   'COMMUNICATION',
#   '4.3',
#   '72065',
#   '13M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 18, 2018',
#   '3.0.7',
#   '4.0 and up'],
#  ['PlacarTv Futebol Ao Vivo',
#   'COMMUNICATION',
#   '4.1',
#   '2063',
#   '4.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 3, 2018',
#   '1.0.3',
#   '4.0 and up'],
#  ['Pocket Prefix Plus',
#   'COMMUNICATION',
#   '4.5',
#   '192',
#   '15M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 12, 2018',
#   'v2.6.0',
#   '3.0 and up'],
#  ['Portable Wi-Fi hotspot',
#   'COMMUNICATION',
#   '3.9',
#   '138129',
#   '2.1M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 6, 2018',
#   '1.5.2.4-23',
#   '2.3 and up'],
#  ['Portable Wi-Fi hotspot Free',
#   'COMMUNICATION',
#   '4.0',
#   '1711',
#   '2.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 11, 2018',
#   '1.2.5.4-11',
#   '2.3 and up'],
#  ['Programi podrške EU',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '5.4M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 15, 2018',
#   '1.0.3',
#   '4.1 and up'],
#  ['Psiphon Pro - The Internet Freedom VPN',
#   'COMMUNICATION',
#   '4.3',
#   '298041',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Puffin Web Browser',
#   'COMMUNICATION',
#   '4.3',
#   '541661',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 9, 2018',
#   '7.5.3.20547',
#   '4.1 and up'],
#  ['QRZ Assistant',
#   'COMMUNICATION',
#   '4.2',
#   '1044',
#   '3.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 30, 2018',
#   '2.0',
#   '4.4 and up'],
#  ['ReadyOp DT',
#   'COMMUNICATION',
#   '4.6',
#   '8',
#   '1.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 6, 2018',
#   '1.0.56',
#   '2.3.3 and up'],
#  ['Ring',
#   'COMMUNICATION',
#   '3.9',
#   '517',
#   '35M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 6, 2018',
#   '20180805',
#   '4.4 and up'],
#  ['RocketDial Dialer & Contacts',
#   'COMMUNICATION',
#   '4.4',
#   '32254',
#   '5.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 4, 2017',
#   '3.9.7',
#   '2.1 and up'],
#  ['Rádio Sol Nascente DF',
#   'COMMUNICATION',
#   'NaN',
#   '12',
#   '1.6M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 28, 2016',
#   '3.1',
#   '2.3 and up'],
#  ['SMS Sender - sluzba.cz',
#   'COMMUNICATION',
#   'NaN',
#   '12',
#   '72k',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 1, 2012',
#   '2.00.00',
#   '2.0 and up'],
#  ['SW-100.tch by Callstel',
#   'COMMUNICATION',
#   '4.0',
#   '1926',
#   '716k',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 16, 2015',
#   '1.3.20',
#   '2.2 and up'],
#  ['Safest Call Blocker',
#   'COMMUNICATION',
#   '4.4',
#   '27540',
#   '3.7M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 5, 2018',
#   '1.26.001',
#   '4.0 and up'],
#  ['Sat-Fi',
#   'COMMUNICATION',
#   '3.6',
#   '97',
#   'Varies with device',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 31, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Sat-Fi Voice',
#   'COMMUNICATION',
#   '3.4',
#   '37',
#   '14M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'November 21, 2014',
#   '2.2.1.5',
#   '2.2 and up'],
#  ['Seznam.cz',
#   'COMMUNICATION',
#   '4.3',
#   '46702',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Should I Answer?',
#   'COMMUNICATION',
#   '4.8',
#   '237468',
#   '8.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   '2018.1.715',
#   '4.0 and up'],
#  ['Skype - free IM & video calls',
#   'COMMUNICATION',
#   '4.1',
#   '10484169',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Skype Lite - Free Video Call & Chat',
#   'COMMUNICATION',
#   '4.2',
#   '33053',
#   '22M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   '1.60.0.31354-release',
#   '4.0.3 and up'],
#  ['SolMail - All-in-One email app',
#   'COMMUNICATION',
#   '4.3',
#   '23707',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 9, 2017',
#   '2.3.17',
#   'Varies with device'],
#  ['Sync.ME – Caller ID & Block',
#   'COMMUNICATION',
#   '4.5',
#   '205739',
#   '17M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   '4.5.4',
#   '4.1 and up'],
#  ['T-Mobile DIGITS',
#   'COMMUNICATION',
#   '3.0',
#   '1820',
#   '33M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 15, 2018',
#   '1.1.50',
#   '4.4 and up'],
#  ['Talkatone: Free Texts, Calls & Phone Number',
#   'COMMUNICATION',
#   '4.1',
#   '132015',
#   '25M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 18, 2018',
#   '6.1',
#   '4.2 and up'],
#  ['Talkie - Wi-Fi Calling, Chats, File Sharing',
#   'COMMUNICATION',
#   '4.2',
#   '4838',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Talkray - Free Calls & Texts',
#   'COMMUNICATION',
#   '4.2',
#   '244863',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 29, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Telegram',
#   'COMMUNICATION',
#   '4.4',
#   '3128611',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Test Server SMS FA',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '1.8M',
#   '5+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 27, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['Text SMS',
#   'COMMUNICATION',
#   '4.5',
#   '349384',
#   '8.2M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 24, 2018',
#   '3.47',
#   '4.0.3 and up'],
#  ['Tiny Call Confirm',
#   'COMMUNICATION',
#   '4.1',
#   '22782',
#   '351k',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'March 25, 2015',
#   '4.2.0',
#   '2.2 and up'],
#  ['TouchPal Keyboard - Fun Emoji & Android Keyboard',
#   'COMMUNICATION',
#   '4.4',
#   '615381',
#   '37M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Communication',
#   'August 2, 2018',
#   '6.7.9.1',
#   '4.0.3 and up'],
#  ['TownWiFi | Wi-Fi Everywhere',
#   'COMMUNICATION',
#   '3.9',
#   '2372',
#   '58M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 2, 2018',
#   '4.2.1',
#   '4.2 and up'],
#  ['TracFone My Account',
#   'COMMUNICATION',
#   '3.6',
#   '20769',
#   '18M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 11, 2018',
#   'R6.0.3',
#   '4.1 and up'],
#  ['Traffic signs BD',
#   'COMMUNICATION',
#   '4.4',
#   '7',
#   '5.3M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 8, 2015',
#   '1.0',
#   '4.1 and up'],
#  ['True Contact - Real Caller ID',
#   'COMMUNICATION',
#   '4.1',
#   '32283',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Truecaller: Caller ID, SMS spam blocking & Dialer',
#   'COMMUNICATION',
#   '4.5',
#   '7820775',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['U - Webinars, Meetings & Messenger',
#   'COMMUNICATION',
#   '4.1',
#   '6601',
#   '31M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 2, 2018',
#   '4.7.0',
#   '4.1 and up'],
#  ['UC Browser - Fast Download Private & Secure',
#   'COMMUNICATION',
#   '4.5',
#   '17714850',
#   '40M',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'August 2, 2018',
#   '12.8.5.1121',
#   '4.0 and up'],
#  ['UC Browser Mini -Tiny Fast Private & Secure',
#   'COMMUNICATION',
#   '4.4',
#   '3648765',
#   '3.3M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'July 18, 2018',
#   '11.4.0',
#   '4.0 and up'],
#  ['Viber Messenger',
#   'COMMUNICATION',
#   '4.3',
#   '11335481',
#   'Varies with device',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 18, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Video Caller Id',
#   'COMMUNICATION',
#   '4.2',
#   '15287',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'January 24, 2018',
#   '2.2.245',
#   '4.0.3 and up'],
#  ['Virtual Walkie Talkie',
#   'COMMUNICATION',
#   '3.8',
#   '21785',
#   '2.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 13, 2015',
#   '1.41',
#   '2.3 and up'],
#  ['Vonage Mobile® Call Video Text',
#   'COMMUNICATION',
#   '4.1',
#   '29208',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'September 28, 2016',
#   '2.9.8',
#   '2.3.3 and up'],
#  ['Voxer Walkie Talkie Messenger',
#   'COMMUNICATION',
#   '4.3',
#   '230564',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['WEB.DE Mail',
#   'COMMUNICATION',
#   '4.3',
#   '226541',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['WeChat',
#   'COMMUNICATION',
#   '4.2',
#   '5387631',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['WeFi - Free Fast WiFi Connect & Find Wi-Fi Map',
#   'COMMUNICATION',
#   '4.0',
#   '13469',
#   '5.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 5, 2018',
#   '4.7.0.2200000',
#   '4.0 and up'],
#  ['Web Browser',
#   'COMMUNICATION',
#   '4.2',
#   '10965',
#   '2.3M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'February 2, 2015',
#   '2.0',
#   '3.0 and up'],
#  ['Web Browser & Explorer',
#   'COMMUNICATION',
#   '4.0',
#   '36901',
#   '6.6M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 4, 2018',
#   '11.8.6',
#   '4.0.3 - 7.1.1'],
#  ['Web Browser for Android',
#   'COMMUNICATION',
#   '4.1',
#   '55110',
#   '4.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 20, 2018',
#   '2.2',
#   '4.0 and up'],
#  ['WhatsApp Business',
#   'COMMUNICATION',
#   '4.4',
#   '137144',
#   '32M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 30, 2018',
#   '2.18.116',
#   '4.0.3 and up'],
#  ['WhatsApp Messenger',
#   'COMMUNICATION',
#   '4.4',
#   '69119316',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['WhatsCall Free Global Phone Call App & Cheap Calls',
#   'COMMUNICATION',
#   '4.6',
#   '1130966',
#   '27M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 6, 2018',
#   '1.9.1.013',
#   '4.0 and up'],
#  ['Who',
#   'COMMUNICATION',
#   '4.3',
#   '2451093',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Whoscall - Caller ID & Block',
#   'COMMUNICATION',
#   '4.4',
#   '552635',
#   '29M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   '6.19.1',
#   '4.1 and up'],
#  ['Wi-Fi Auto-connect',
#   'COMMUNICATION',
#   '3.8',
#   '15036',
#   '253k',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2015',
#   '1.2.0',
#   '1.6 and up'],
#  ['WiFi Access Point (hotspot)',
#   'COMMUNICATION',
#   '3.9',
#   '684',
#   '61k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 14, 2015',
#   '1.1.2',
#   '2.3 and up'],
#  ['X Browser',
#   'COMMUNICATION',
#   '4.0',
#   '142',
#   '2.5M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'December 31, 2017',
#   '1.1.1',
#   '4.0 and up'],
#  ['Xperia Link™',
#   'COMMUNICATION',
#   '4.1',
#   '45487',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'October 27, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['Yahoo Mail – Stay Organized',
#   'COMMUNICATION',
#   '4.3',
#   '4188345',
#   '16M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 18, 2018',
#   '5.29.3',
#   '4.4 and up'],
#  ['Your Freedom VPN Client',
#   'COMMUNICATION',
#   '4.0',
#   '74497',
#   '5.3M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'May 19, 2018',
#   '20180518-01',
#   '4.0 and up'],
#  ['Zalo – Video Call',
#   'COMMUNICATION',
#   '4.2',
#   '1042170',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['ZenUI Dialer & Contacts',
#   'COMMUNICATION',
#   '4.5',
#   '437674',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['[EF]ShoutBox',
#   'COMMUNICATION',
#   'NaN',
#   '3',
#   '2.5M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'August 7, 2018',
#   'Build 54',
#   '4.0.3 and up'],
#  ['[verify-U] VideoIdent',
#   'COMMUNICATION',
#   '2.9',
#   '83',
#   '13M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 26, 2018',
#   '2.4.0',
#   '5.0 and up'],
#  ['chat dz',
#   'COMMUNICATION',
#   '5.0',
#   '8',
#   '29M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'March 14, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['chomp SMS',
#   'COMMUNICATION',
#   '4.3',
#   '335646',
#   '8.3M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 26, 2018',
#   '7.21',
#   '2.3 and up'],
#  ['cluster.dk',
#   'COMMUNICATION',
#   'NaN',
#   '49',
#   '1.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 25, 2013',
#   '1.0.2',
#   '2.3 and up'],
#  ['ei',
#   'COMMUNICATION',
#   'NaN',
#   '2',
#   '4.5M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'July 16, 2018',
#   '0.0.10',
#   '4.4 and up'],
#  ['free video calls and chat',
#   'COMMUNICATION',
#   '4.2',
#   '594728',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 19, 2018',
#   '7.3(800241)',
#   '4.4 and up'],
#  ['imo beta free calls and text',
#   'COMMUNICATION',
#   '4.3',
#   '659395',
#   '11M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 7, 2018',
#   '9.8.000000010492',
#   '4.0 and up'],
#  ['imo free video calls and chat',
#   'COMMUNICATION',
#   '4.3',
#   '4785988',
#   '11M',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'June 8, 2018',
#   '9.8.000000010501',
#   '4.0 and up'],
#  ['love sms good morning',
#   'COMMUNICATION',
#   '4.2',
#   '10',
#   '3.1M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 28, 2016',
#   '1.0',
#   '2.3 and up'],
#  ['m:go BiH',
#   'COMMUNICATION',
#   '3.2',
#   '559',
#   '6.0M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 25, 2018',
#   '3.4',
#   '3.0 and up'],
#  ['mail.co.uk Mail',
#   'COMMUNICATION',
#   '4.2',
#   '21',
#   '8.7M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 24, 2018',
#   '1.1.0',
#   '4.0.3 and up'],
#  ['mail.com mail',
#   'COMMUNICATION',
#   '4.2',
#   '44706',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['myMail – Email for Hotmail, Gmail and Outlook Mail',
#   'COMMUNICATION',
#   '4.5',
#   '305218',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['mysms SMS Text Messaging Sync',
#   'COMMUNICATION',
#   '4.3',
#   '37320',
#   '8.4M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'July 30, 2018',
#   '6.5.1',
#   '4.0.3 and up'],
#  ['retteMi.ch',
#   'COMMUNICATION',
#   'NaN',
#   '31',
#   'Varies with device',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Communication',
#   'April 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['tournaments and more.aj.2',
#   'COMMUNICATION',
#   'NaN',
#   '0',
#   '4.2M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Communication',
#   'September 25, 2017',
#   '4.3',
#   '2.3 and up']]

# %% [markdown]
# **As we can see, apps like Skype, Google Chrome, WhatsApp and AT&T Messenger fall into the "Communication". Let's check other categories, starting by the second on average installs: "Video Players".**

# %%
video_players_apps = []

for row in android_free:
    genre = row[1]
    if genre == 'VIDEO_PLAYERS':
        video_players_apps.append(row)

# %%
sorted (video_players_apps)
# Out:
# [['4K VIDEO PLAYER ULTRA HD',
#   'VIDEO_PLAYERS',
#   '3.7',
#   '20',
#   '24M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 1, 2017',
#   '7.0',
#   '2.3.3 and up'],
#  ['A-B repeater',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '32',
#   '239k',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 18, 2018',
#   '1.8',
#   '3.0 and up'],
#  ['A-Z Screen Recorder -',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '17',
#   '3.7M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 23, 2018',
#   '1.0',
#   '4.4 and up'],
#  ['AB Repeat Player',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '1628',
#   '18M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 6, 2018',
#   '4.1.1',
#   '4.4 and up'],
#  ['ACTIVEON CX & CX GOLD',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '439',
#   '35M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 4, 2016',
#   '0.7.9',
#   '4.0 and up'],
#  ['AJ Player',
#   'VIDEO_PLAYERS',
#   '4.8',
#   '18',
#   '1.7M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 22, 2018',
#   '1.6.3.1',
#   '5.0 and up'],
#  ['AK Lodi Films',
#   'VIDEO_PLAYERS',
#   '4.9',
#   '23',
#   '2.1M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 11, 2015',
#   '1.1',
#   '4.0 and up'],
#  ['AV-IPTV',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '43',
#   '44M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 27, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['AW Screen Recorder No Root',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '1659',
#   '3.7M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 6, 2017',
#   '1.1',
#   '5.0 and up'],
#  ['AX Player -Nougat Video Player',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '15765',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'September 12, 2014',
#   '2.0',
#   '2.2 and up'],
#  ['AX Video Player',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '569',
#   '2.6M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'November 11, 2015',
#   '1.0.9',
#   '3.0 and up'],
#  ['AZ Screen Recorder - No Root',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '751911',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 2, 2018',
#   'Varies with device',
#   '5.0 and up'],
#  ['ActionDirector Video Editor - Edit Videos Fast',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '74531',
#   '32M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 15, 2018',
#   '2.12.0',
#   '4.3 and up'],
#  ['Adobe Premiere Clip',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '39495',
#   '59M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 26, 2018',
#   '1.1.4.1296',
#   '4.4 and up'],
#  ['AfreecaTV',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '381023',
#   '53M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 26, 2018',
#   '2.7.8',
#   '4.0 and up'],
#  ['All Video Downloader',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '165723',
#   '1.6M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 4, 2018',
#   '7.5.9',
#   '4.0 and up'],
#  ['All Video Downloader 2018',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '7557',
#   '5.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 25, 2018',
#   '1.0.1',
#   '4.4 and up'],
#  ['AndStream - Streaming Download',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '38607',
#   '2.9M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 19, 2017',
#   '3.1.8',
#   '2.3 and up'],
#  ['Art of F J Taylor',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '2',
#   '1.5M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 23, 2015',
#   '1.0.2',
#   '4.3 and up'],
#  ['Ay',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '11',
#   '3.6M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'May 4, 2018',
#   '1.0.261',
#   '2.3 and up'],
#  ['Ay Sabz Gunbad Waly',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '4',
#   '3.9M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'September 11, 2017',
#   '1.1',
#   '4.0 and up'],
#  ['BC iptv player',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '8',
#   '14M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'October 12, 2017',
#   'Final',
#   '4.0 and up'],
#  ['BG MUSIC PLAYER - MUSIC PLAYER',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '0',
#   '8.6M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 26, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['BG video - floating video - background video',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '64',
#   '2.0M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 21, 2018',
#   '2.0',
#   '4.0 and up'],
#  ['BGCN TV',
#   'VIDEO_PLAYERS',
#   '3.4',
#   '4334',
#   '4.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'November 4, 2015',
#   '3.1.891',
#   'Varies with device'],
#  ['BK News Channel',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '277',
#   '6.8M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 16, 2016',
#   '1.01',
#   '2.3 and up'],
#  ['BR Series',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '1016',
#   '13M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'May 28, 2018',
#   '6.0',
#   '4.1 and up'],
#  ['BR Video Player',
#   'VIDEO_PLAYERS',
#   '4.0',
#   '46',
#   '3.1M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 20, 2015',
#   '1.0.6',
#   '3.0 and up'],
#  ['BS player remote',
#   'VIDEO_PLAYERS',
#   '3.5',
#   '54',
#   '186k',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 22, 2013',
#   '1.0',
#   '2.2 and up'],
#  ['BSPlayer ARMv7 VFP CPU support',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '9966',
#   '5.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 31, 2017',
#   '1.23',
#   '2.1 and up'],
#  ['BSPlayer FREE',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '138337',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['BZ Langenthaler Tagblatt',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '22',
#   '8.5M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '7.5.9.1',
#   '4.1 and up'],
#  ['Bc Vod',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '1',
#   '62M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 17, 2018',
#   '1.2',
#   '4.2 and up'],
#  ['BitTorrent®- Torrent Downloads',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '641219',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 26, 2018',
#   '5.2.2',
#   '4.1 and up'],
#  ['BluTV',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '28835',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Bx-WiFi-GI',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '0',
#   '21M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 15, 2017',
#   '1.3.6',
#   '4.1 and up'],
#  ['CI Stream',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '0',
#   '14M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 12, 2018',
#   '1.0',
#   '4.4 and up'],
#  ['CINE BR',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '23',
#   '7.5M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 29, 2018',
#   '1',
#   '4.2 and up'],
#  ['CJ Camcorder',
#   'VIDEO_PLAYERS',
#   '4.7',
#   '3',
#   '2.8M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'November 26, 2017',
#   '1.0',
#   '4.0 and up'],
#  ['CJ VLC HD Remote (+ Stream)',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '4074',
#   '1.3M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'November 13, 2013',
#   '1.2.4',
#   '2.1 and up'],
#  ['CX Monthly Tech News',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '2',
#   '6.9M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 9, 2016',
#   '6.1.0',
#   '4.0 and up'],
#  ['Cartoon Network App',
#   'VIDEO_PLAYERS',
#   '4.0',
#   '119202',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Video Players & Editors;Music & Video',
#   'June 21, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Casper Ssinema',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '1261',
#   '2.5M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'October 30, 2014',
#   '1.0',
#   '2.3 and up'],
#  ['Code',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '239242',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'November 19, 2017',
#   '17.6',
#   '5.0 and up'],
#  ['DG Screen Recorder',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '12',
#   '2.9M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'October 20, 2015',
#   '1.7',
#   '5.0 and up'],
#  ['DG UPnP Player Free',
#   'VIDEO_PLAYERS',
#   '3.2',
#   '39',
#   '12M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 18, 2016',
#   '2.0',
#   '4.0.3 and up'],
#  ['DG Video Editor',
#   'VIDEO_PLAYERS',
#   '4.0',
#   '486',
#   '2.5M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'September 6, 2016',
#   '1.0.3',
#   '4.4 and up'],
#  ['DR TV',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '6716',
#   '4.7M',
#   '500,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Video Players & Editors',
#   'June 25, 2018',
#   '3.0.6',
#   '4.4 and up'],
#  ['DS photo',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '7335',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 17, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['DS video',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '12443',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['DU Privacy-hide apps、sms、file',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '21762',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 16, 2017',
#   'Varies with device',
#   '4.0.3 and up'],
#  ['DU Recorder – Screen Recorder, Video Editor, Live',
#   'VIDEO_PLAYERS',
#   '4.8',
#   '2588730',
#   '9.7M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 30, 2018',
#   '1.7.1.3',
#   '5.0 and up'],
#  ['DV Lottery Photo',
#   'VIDEO_PLAYERS',
#   '2.9',
#   '23',
#   '4.0M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 16, 2016',
#   '1.1',
#   '3.0 and up'],
#  ['DZ Popup Video Player',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '83',
#   '4.5M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 16, 2018',
#   '4.6',
#   '4.1 and up'],
#  ['Downvids Helper - One touch DW',
#   'VIDEO_PLAYERS',
#   '3.5',
#   '197',
#   '9.8M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'February 5, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  ['Droid Zap by Motorola',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '2093',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'February 3, 2015',
#   'Varies with device',
#   'Varies with device'],
#  ['Dubsmash',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '1971777',
#   '29M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'May 11, 2018',
#   '2.35.8',
#   '4.1 and up'],
#  ['EC MANAGER',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '2',
#   '17M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 13, 2018',
#   '8.3.13.6',
#   '4.1 and up'],
#  ['EF Sidekick',
#   'VIDEO_PLAYERS',
#   '3.1',
#   '36',
#   'Varies with device',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 20, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['EML UPnP-AV Control Point',
#   'VIDEO_PLAYERS',
#   '3.0',
#   '78',
#   '322k',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'September 19, 2013',
#   '1.3',
#   '1.6 and up'],
#  ['ES Audio Player ( Shortcut )',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '1236',
#   '33k',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 17, 2013',
#   '1.1',
#   '2.2 and up'],
#  ['ES-IPTV',
#   'VIDEO_PLAYERS',
#   '4.0',
#   '944',
#   '11M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'October 15, 2017',
#   '4.2.1',
#   '4.1 and up'],
#  ['EZ TV Player',
#   'VIDEO_PLAYERS',
#   '3.5',
#   '51',
#   '11M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 26, 2018',
#   '8.0.9',
#   '5.0 and up'],
#  ['EZ Usenet for Easynews®',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '244',
#   'Varies with device',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 23, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['EZ Web Video Cast | Chromecast',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '1276',
#   '4.6M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 14, 2017',
#   '1.0',
#   '4.4 and up'],
#  ['EZ game screen recorder with audio 1080P',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '40',
#   '3.9M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 13, 2017',
#   '1.0.0',
#   '5.0 and up'],
#  ['EZ-SEE',
#   'VIDEO_PLAYERS',
#   '2.8',
#   '71',
#   '10M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 18, 2018',
#   '3.08',
#   '5.0 and up'],
#  ['EZCast – Cast Media to TV',
#   'VIDEO_PLAYERS',
#   '3.6',
#   '32112',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 4, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Ez Screen Recorder (no ad)',
#   'VIDEO_PLAYERS',
#   '4.7',
#   '8696',
#   '14M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 3, 2018',
#   '2.1.4',
#   '5.0 and up'],
#  ['FilmoraGo - Free Video Editor',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '238459',
#   '35M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 6, 2018',
#   '3.1.4',
#   '4.2 and up'],
#  ['Free TV series',
#   'VIDEO_PLAYERS',
#   '3.7',
#   '400',
#   '7.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'May 28, 2018',
#   'v1.0.3',
#   '4.0.3 and up'],
#  ['FrostWire: Torrent Downloader & Music Player',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '253207',
#   '13M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 2, 2018',
#   '2.0.7',
#   '4.4 and up'],
#  ['Funny videos for whatsapp',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '3066',
#   '9.0M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 17, 2017',
#   '1.7',
#   '4.0.3 and up'],
#  ['Furrion ES Control',
#   'VIDEO_PLAYERS',
#   '1.8',
#   '26',
#   '2.7M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'September 29, 2016',
#   '1.0',
#   '4.2 and up'],
#  ['G Guide Program Guide (SOFTBANK EMOBILE WILLCOM version)',
#   'VIDEO_PLAYERS',
#   '3.1',
#   '2689',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 18, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['GoAction',
#   'VIDEO_PLAYERS',
#   '3.6',
#   '1522',
#   '65M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 17, 2018',
#   'V1.5.3',
#   '4.4 and up'],
#  ['GoPlus Cam',
#   'VIDEO_PLAYERS',
#   '3.5',
#   '3484',
#   '41M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 18, 2017',
#   '3.0.1',
#   '4.0.3 and up'],
#  ['Google Play Movies & TV',
#   'VIDEO_PLAYERS',
#   '3.7',
#   '906384',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['HD Movie Video Player',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '18699',
#   '4.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 27, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['HD Video Download for Facebook',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '20755',
#   '17M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 16, 2018',
#   '4.0.3',
#   '4.1 and up'],
#  ['HD Video Downloader : 2018 Best video mate',
#   'VIDEO_PLAYERS',
#   '3.7',
#   '430643',
#   '4.9M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 31, 2018',
#   '2.5.0',
#   '4.1 and up'],
#  ['HD Video Player',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '1551',
#   '2.9M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 25, 2018',
#   '1.1',
#   '4.1 and up'],
#  ['HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '171',
#   '4.8M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 10, 2017',
#   '1.1',
#   '4.1 and up'],
#  ['HD Video Player - Video & MP3 Player | AV Player |',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '22',
#   '19M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 6, 2018',
#   '1.0.1',
#   '4.0 and up'],
#  ['HD VideoDownlaoder For Fb : XXVideo Downloader',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '61',
#   '6.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 30, 2018',
#   '1.0.3',
#   '4.0.3 and up'],
#  ['HTC Gallery',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '45744',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 3, 2016',
#   '9.51.755029',
#   '4.4 and up'],
#  ['HTC Service － DLNA',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '3484',
#   '3.0M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 3, 2015',
#   '7.10.621414',
#   '5.0 and up'],
#  ['HTC Service—Video Player',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '6449',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'February 13, 2015',
#   '6.5.852058',
#   '5.0 and up'],
#  ['Inst Download - Video & Photo',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '148715',
#   '3.3M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 20, 2017',
#   '2.0',
#   '4.0 and up'],
#  ['Iqiyi (for tablet)',
#   'VIDEO_PLAYERS',
#   '3.6',
#   '12764',
#   '25M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'July 11, 2018',
#   '7.1',
#   '4.0 and up'],
#  ['KineMaster – Pro Video Editor',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '1013867',
#   '32M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '4.5.0.10701.GP',
#   '4.1 and up'],
#  ['LIKE – Magic Video Maker & Community',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '921868',
#   '47M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 4, 2018',
#   '2.4.11',
#   '4.0 and up'],
#  ['List iptv FR',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '1',
#   '2.9M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 22, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['M-Sight Pro',
#   'VIDEO_PLAYERS',
#   '3.3',
#   '30',
#   '15M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 25, 2018',
#   '3.1.0.1-r4',
#   '4.0 and up'],
#  ['MX Player',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '6474672',
#   'Varies with device',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Magisto Video Editor & Maker',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '960726',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['MelifeCam-M',
#   'VIDEO_PLAYERS',
#   '3.5',
#   '81',
#   '22M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 21, 2016',
#   'R1.3.21.3',
#   '4.1 and up'],
#  ['MiniMovie - Free Video and Slideshow Editor',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '504823',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 13, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Mobizen Screen Recorder for LG - Record, Capture',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '58820',
#   '37M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 26, 2018',
#   '3.5.1.8',
#   '4.4 and up'],
#  ['Mobizen Screen Recorder for SAMSUNG',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '953894',
#   '37M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 26, 2018',
#   '3.5.1.8',
#   'Varies with device'],
#  ['Motorola FM Radio',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '54815',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Motorola Gallery',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '121916',
#   '23M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'January 25, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['Movie Downloader Torrent : Az Torrent',
#   'VIDEO_PLAYERS',
#   '4.7',
#   '70',
#   '14M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 7, 2018',
#   '1.9',
#   '4.1 and up'],
#  ['Multiple Videos at Same Time',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '4706',
#   '1.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 19, 2018',
#   'Z (Special Edition R9)',
#   '4.4 and up'],
#  ['Music - Mp3 Player',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '259605',
#   '3.1M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '1.6.1',
#   '4.0.3 and up'],
#  ['Music for Youtube - Tube Music BG, Red+',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '47',
#   '8.7M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'September 23, 2017',
#   '1.10',
#   '4.2 and up'],
#  ['Naruto Shippuden - Watch Free!',
#   'VIDEO_PLAYERS',
#   '3.9',
#   '141515',
#   '5.7M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'April 23, 2014',
#   '0.6.0',
#   '2.3 and up'],
#  ['Nero AirBurn',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '1008',
#   '1.7M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'June 26, 2015',
#   '1.0.9',
#   '4.0 and up'],
#  ['OBJECTIVE',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '19738',
#   '33M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 7, 2018',
#   '9.7.6',
#   '4.0 and up'],
#  ['Omlet Arcade - Stream, Meet, Play',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '169965',
#   '14M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 2, 2018',
#   '1.32.1',
#   '4.3 and up'],
#  ['OnePlus Gallery',
#   'VIDEO_PLAYERS',
#   '3.8',
#   '5555',
#   '64M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 12, 2018',
#   '2.6.71',
#   '7.1 and up'],
#  ['Play Tube',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '15874',
#   '5.4M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 5, 2018',
#   '1.2',
#   '4.1 and up'],
#  ['PowerDirector Video Editor App: 4K, Slow Mo & More',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '714665',
#   '50M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 24, 2018',
#   '4.13.3',
#   '4.3 and up'],
#  ['Q-See Plus',
#   'VIDEO_PLAYERS',
#   '2.2',
#   '32',
#   '33M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 9, 2018',
#   '3.1.0',
#   '4.0.3 and up'],
#  ['Quik – Free Video Editor for photos, clips, music',
#   'VIDEO_PLAYERS',
#   '4.7',
#   '696665',
#   '91M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 5, 2018',
#   '4.7.4.3869-7b2372c3e',
#   '5.0 and up'],
#  ['Ringdroid',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '326232',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 3, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['SVT Play',
#   'VIDEO_PLAYERS',
#   '3.7',
#   '11549',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'July 13, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Samsung Video Library',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '25922',
#   '6.1M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 9, 2018',
#   '1.4.08.2',
#   '7.0 and up'],
#  ["Sketch 'n' go",
#   'VIDEO_PLAYERS',
#   '3.8',
#   '3965',
#   '6.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 26, 2018',
#   '2.2.9',
#   '4.1 and up'],
#  ['Tencent Video - Supporting the whole network',
#   'VIDEO_PLAYERS',
#   '3.5',
#   '13205',
#   '44M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'July 31, 2018',
#   '6.2.2.17136',
#   '3.0 and up'],
#  ['Ustream',
#   'VIDEO_PLAYERS',
#   '4.0',
#   '93638',
#   '7.3M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Video Players & Editors',
#   'July 11, 2018',
#   '3.2.2',
#   '4.1 and up'],
#  ['VLC for Android',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '1032076',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 30, 2018',
#   'Varies with device',
#   '2.3 and up'],
#  ['VMate',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '192677',
#   '17M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '1.78',
#   '4.0.3 and up'],
#  ['VPlayer',
#   'VIDEO_PLAYERS',
#   '3.6',
#   '5639',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 12, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['VUE: video editor & camcorder',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '38630',
#   '89M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 5, 2018',
#   '2.1.6',
#   '4.4 and up'],
#  ['VidPlay',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '3546',
#   '3.7M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 27, 2018',
#   '2.0.19',
#   '4.1 and up'],
#  ['Video Downloader',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '59089',
#   '5.4M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '1.0.8',
#   '4.4 and up'],
#  ['Video Downloader - for Instagram Repost App',
#   'VIDEO_PLAYERS',
#   '4.8',
#   '332623',
#   '4.6M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 27, 2018',
#   '1.1.58',
#   '4.1 and up'],
#  ['Video Downloader for FB : Video Download with Link',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '1060',
#   '3.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 20, 2017',
#   '2.1',
#   '4.0 and up'],
#  ['Video Editor',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '159622',
#   '23M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors;Creativity',
#   'July 17, 2018',
#   '6.14.091',
#   '4.3 and up'],
#  ['Video Editor,Crop Video,Movie Video,Music,Effects',
#   'VIDEO_PLAYERS',
#   '4.7',
#   '53006',
#   '44M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '1.5.1',
#   '4.4 and up'],
#  ['Video Player All Format',
#   'VIDEO_PLAYERS',
#   '4.8',
#   '259003',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 3, 2018',
#   'Varies with device',
#   '4.3 and up'],
#  ['Video Player All Format for Android',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '3930',
#   '3.3M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 26, 2018',
#   '1.1.7',
#   '4.0.3 and up'],
#  ['Video Status',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '6685',
#   '4.0M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 2, 2018',
#   '1.1.4',
#   '4.1 and up'],
#  ['Video Wallpaper Show',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '0',
#   '13M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 26, 2018',
#   '3.1',
#   '4.0.3 and up'],
#  ['Video.Guru - Video Maker',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '36969',
#   '27M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 6, 2018',
#   '1.137.22',
#   '4.3 and up'],
#  ['VideoShow-Video Editor, Video Maker, Beauty Camera',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '4016834',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Videos downloader for Facebook:fast fb video saver',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '20',
#   '5.1M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 27, 2018',
#   '1.0.0',
#   '4.0.3 and up'],
#  ['Vigo Video',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '1615596',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 3, 2018',
#   'Varies with device',
#   '4.0.3 and up'],
#  ['VivaVideo - Video Editor & Photo Movie',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '9879473',
#   '40M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 4, 2018',
#   '7.2.1',
#   '4.1 and up'],
#  ['Vote for',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '193381',
#   '17M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 3, 2018',
#   '1.78',
#   '4.0.3 and up'],
#  ['Vuze Torrent Downloader',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '24565',
#   '5.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 4, 2016',
#   '2.1',
#   '2.3.3 and up'],
#  ['W Box VMS',
#   'VIDEO_PLAYERS',
#   '1.9',
#   '105',
#   '9.1M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'January 9, 2017',
#   '4.0.4',
#   '2.3.3 and up'],
#  ['W Box VMS HD',
#   'VIDEO_PLAYERS',
#   '2.5',
#   '24',
#   '16M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'January 4, 2017',
#   '4.0.3',
#   '3.0 and up'],
#  ['WiFi Baby Monitor - NannyCam',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '29867',
#   '1.7M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 24, 2017',
#   '3.1.0 (build 1210)',
#   '2.3.3 and up'],
#  ['XX HD Video downloader-Free Video Downloader',
#   'VIDEO_PLAYERS',
#   '4.1',
#   '7624',
#   '6.0M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'April 20, 2018',
#   '1.9',
#   '4.0.3 and up'],
#  ['YouCut - Video Editor & Video Maker, No Watermark',
#   'VIDEO_PLAYERS',
#   '4.6',
#   '98819',
#   '27M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'August 6, 2018',
#   '1.251.54',
#   '4.3 and up'],
#  ['YouTube',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '25655305',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['YouTube Studio',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '436921',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'June 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['YourTube Video Views BG',
#   'VIDEO_PLAYERS',
#   'NaN',
#   '8',
#   '2.5M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'November 12, 2015',
#   '1.1.1',
#   '4.0 and up'],
#  ['amazer - Global Kpop Video Community',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '1215',
#   '23M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Video Players & Editors',
#   'July 20, 2018',
#   '1.5.4',
#   '4.1 and up'],
#  ['bgtime.tv',
#   'VIDEO_PLAYERS',
#   '3.4',
#   '694',
#   'Varies with device',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['dv Prompter',
#   'VIDEO_PLAYERS',
#   '3.7',
#   '321',
#   '1.3M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'March 14, 2017',
#   '1.2.9',
#   '4.2 and up'],
#  ['ek tuhi',
#   'VIDEO_PLAYERS',
#   '4.7',
#   '316',
#   '2.8M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 4, 2014',
#   '1.0',
#   '4.0 and up'],
#  ['iMediaShare – Photos & Music',
#   'VIDEO_PLAYERS',
#   '4.2',
#   '104551',
#   '18M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'December 19, 2017',
#   '1.0.10',
#   '2.2 and up'],
#  ['iPlayIT for YouTube VR Player',
#   'VIDEO_PLAYERS',
#   '4.3',
#   '5879',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Video Players & Editors',
#   'June 12, 2018',
#   'Varies with device',
#   '4.1 and up'],
#  ['iSmart DV',
#   'VIDEO_PLAYERS',
#   '3.6',
#   '5692',
#   '31M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'July 27, 2018',
#   'R1.4.14.B1.4',
#   '4.1 and up'],
#  ['video player',
#   'VIDEO_PLAYERS',
#   '4.4',
#   '26421',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'May 30, 2018',
#   '3.4.5',
#   '4.1 and up'],
#  ['video player for android',
#   'VIDEO_PLAYERS',
#   '4.5',
#   '351168',
#   '13M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Video Players & Editors',
#   'October 18, 2016',
#   '2.0.0',
#   '2.3 and up']]

# %% [markdown]
# **Video players category has an interesting panorama, including video capturing solutions, players and editors. Now with the third place, Social.**

# %%
social_apps = []

for row in android_free:
    genre = row[1]
    if genre == 'SOCIAL':
        social_apps.append(row)

# %%
sorted (social_apps)
# Out:
# [['+Download 4 Instagram Twitter',
#   'SOCIAL',
#   '4.5',
#   '40467',
#   '22M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 2, 2018',
#   '5.03',
#   '4.1 and up'],
#  ['Alarm.fo – choose your info',
#   'SOCIAL',
#   '4.4',
#   '19',
#   '3.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 29, 2018',
#   '1.4.8',
#   '4.1 and up'],
#  ['All Social Networks',
#   'SOCIAL',
#   '4.2',
#   '22650',
#   '1.5M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 21, 2018',
#   '2.4.12',
#   '4.0 and up'],
#  ['Alumni BJ',
#   'SOCIAL',
#   'NaN',
#   '2',
#   '5.4M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'November 8, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['Amino: Communities and Chats',
#   'SOCIAL',
#   '4.8',
#   '1264084',
#   '62M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 7, 2018',
#   '1.8.19179',
#   '4.0.3 and up'],
#  ['Amleen Ey',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '19M',
#   '1+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 24, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['Anime et Manga Amino en Français',
#   'SOCIAL',
#   '4.8',
#   '3782',
#   '63M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['Au Pair',
#   'SOCIAL',
#   '3.6',
#   '58',
#   '15M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 14, 2017',
#   '1.3.0',
#   '4.2 and up'],
#  ['Auto DM for Twitter 🔥',
#   'SOCIAL',
#   '3.4',
#   '44',
#   '6.3M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 21, 2018',
#   'HTTPs',
#   '4.1 and up'],
#  ['B-Messenger Video Chat',
#   'SOCIAL',
#   '4.1',
#   '12495',
#   '19M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 19, 2017',
#   '7.1.1',
#   '2.3 and up'],
#  ['BA 3 Banjarmasin',
#   'SOCIAL',
#   'NaN',
#   '2',
#   '5.9M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 28, 2018',
#   '1.0.1',
#   '4.4 and up'],
#  ['BG LINKED (BGLINKED)',
#   'SOCIAL',
#   '4.7',
#   '22',
#   '11M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'January 19, 2018',
#   'v2.0.02_prod',
#   '4.1 and up'],
#  ['BGKontakti Bayern BG Kontakti',
#   'SOCIAL',
#   'NaN',
#   '32',
#   '7.8M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 25, 2016',
#   '1.6',
#   '3.0 and up'],
#  ['BGKontakti London BG Kontakti',
#   'SOCIAL',
#   'NaN',
#   '4',
#   '8.9M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'March 23, 2017',
#   '1.2',
#   '3.0 and up'],
#  ['BGKontakti Vienna BG Kontakti',
#   'SOCIAL',
#   '4.8',
#   '111',
#   '5.9M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 18, 2018',
#   '2.42',
#   '4.1 and up'],
#  ['BH Connect',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '32M',
#   '1+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 22, 2018',
#   '1.4.4',
#   '4.0.3 and up'],
#  ['BIGO LIVE - Live Stream',
#   'SOCIAL',
#   '4.4',
#   '2349421',
#   '39M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 27, 2018',
#   '4.1.0',
#   '4.0 and up'],
#  ['BK Traffic Control cum Chart',
#   'SOCIAL',
#   '4.7',
#   '549',
#   '17M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 29, 2016',
#   '3.0.1',
#   '3.0 and up'],
#  ['BOO! - Next Generation Messenger',
#   'SOCIAL',
#   '3.5',
#   '20675',
#   '96M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 2, 2018',
#   '4.4.0',
#   '5.0 and up'],
#  ['BR Chat Bot',
#   'SOCIAL',
#   '1.9',
#   '16',
#   '2.6M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 30, 2016',
#   '1.0',
#   '4.0 and up'],
#  ['BT Communicator',
#   'SOCIAL',
#   '3.8',
#   '32',
#   '1.6M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'December 16, 2016',
#   '1.0',
#   '1.6 and up'],
#  ['BT Dating -Find your match, help cupid, be social',
#   'SOCIAL',
#   '4.1',
#   '158',
#   '26M',
#   '50,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 19, 2018',
#   '2.3',
#   '4.1 and up'],
#  ['Badoo - Free Chat & Dating App',
#   'SOCIAL',
#   '4.3',
#   '3781770',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Banjo',
#   'SOCIAL',
#   '4.2',
#   '58341',
#   '9.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 25, 2015',
#   '4.6.2.0',
#   '2.3 and up'],
#  ['Best DP and Status',
#   'SOCIAL',
#   '4.2',
#   '93',
#   '5.6M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'November 29, 2017',
#   '7.6.5',
#   '4.1 and up'],
#  ['Black Social',
#   'SOCIAL',
#   '4.6',
#   '22',
#   '8.7M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 5, 2018',
#   '31.1.4',
#   '4.3 and up'],
#  ['Blogaway for Android (Blogger)',
#   'SOCIAL',
#   '3.7',
#   '4253',
#   '4.1M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 31, 2018',
#   '7.0.7',
#   '4.0.3 and up'],
#  ['Blogger',
#   'SOCIAL',
#   '3.7',
#   '138026',
#   '2.7M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'February 29, 2016',
#   '2.1.3',
#   '2.1 and up'],
#  ["Bloglovin'",
#   'SOCIAL',
#   '3.9',
#   '8936',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 18, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Br Browser',
#   'SOCIAL',
#   '4.9',
#   '29',
#   '2.5M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'March 20, 2018',
#   '5.0',
#   '5.0 and up'],
#  ['C.P. CERVANTES (TOBARRA)',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '4.9M',
#   '5+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 24, 2018',
#   '8.2',
#   '4.0.3 and up'],
#  ['CB Heroes',
#   'SOCIAL',
#   '5.0',
#   '5',
#   '1.8M',
#   '5+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 4, 2018',
#   '1.2.4',
#   '5.0 and up'],
#  ['CG Districts',
#   'SOCIAL',
#   '3.8',
#   '14',
#   'Varies with device',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['CJ Gospel Hour',
#   'SOCIAL',
#   '5.0',
#   '7',
#   '18M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 25, 2018',
#   '1.0',
#   '4.4 and up'],
#  ['CP Dialer',
#   'SOCIAL',
#   '4.3',
#   '64',
#   '3.3M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 22, 2018',
#   '2.9.0',
#   '4.1 and up'],
#  ['Chat For Strangers - Video Chat',
#   'SOCIAL',
#   '3.4',
#   '622',
#   'Varies with device',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'May 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Check Your Visitors on FB ?',
#   'SOCIAL',
#   '3.6',
#   '40',
#   '1.5M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'February 17, 2017',
#   '4.4',
#   '4.2 and up'],
#  ['Coupe Adhémar EY 2017',
#   'SOCIAL',
#   'NaN',
#   '6',
#   '10M',
#   '50+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'December 26, 2016',
#   '1.3',
#   '4.1 and up'],
#  ['Couple - Relationship App',
#   'SOCIAL',
#   '4.0',
#   '33249',
#   '8.4M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'March 5, 2015',
#   '1.8.0',
#   '2.3 and up'],
#  ['Cyprus Police',
#   'SOCIAL',
#   '4.2',
#   '226',
#   '15M',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Social',
#   'January 31, 2018',
#   '1.122.250.1421',
#   '2.2 and up'],
#  ['DB Event App',
#   'SOCIAL',
#   '2.4',
#   '37',
#   '37M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 25, 2017',
#   '1.0',
#   '4.1 and up'],
#  ['DC Comics Amino',
#   'SOCIAL',
#   '4.9',
#   '117',
#   '63M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['DF BugMeNot',
#   'SOCIAL',
#   'NaN',
#   '7',
#   '1.4M',
#   '500+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'October 29, 2015',
#   '1.0',
#   '5.0 and up'],
#  ['DK Murali',
#   'SOCIAL',
#   '4.8',
#   '65',
#   '7.1M',
#   '500+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'February 25, 2017',
#   '1.1.2',
#   '4.1 and up'],
#  ['DM Me - Chat',
#   'SOCIAL',
#   '2.9',
#   '90',
#   '30M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 9, 2018',
#   '1.0',
#   '4.0.3 and up'],
#  ['DM Storage (for twitter)',
#   'SOCIAL',
#   '3.2',
#   '6',
#   '458k',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'November 26, 2014',
#   '1.0',
#   '4.1 and up'],
#  ['DM for IG 😘 - Image & Video Saver for Instagram',
#   'SOCIAL',
#   '3.7',
#   '55',
#   '3.7M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 3, 2018',
#   '3.20.3',
#   '4.4 and up'],
#  ['DN Blog',
#   'SOCIAL',
#   '5.0',
#   '20',
#   '4.2M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 23, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['DP Display Pictures Life Quotes Motivational GM',
#   'SOCIAL',
#   '4.4',
#   '39',
#   '11M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'January 1, 2018',
#   '20',
#   '4.1 and up'],
#  ['DP and Status for WhatsApp 2018',
#   'SOCIAL',
#   '4.5',
#   '787',
#   '6.9M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'February 17, 2018',
#   '2.4.2',
#   '4.0.3 and up'],
#  ['DV Statistics',
#   'SOCIAL',
#   '4.2',
#   '6',
#   '2.7M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'October 8, 2015',
#   '1.2',
#   '4.0.3 and up'],
#  ['DW Streaming',
#   'SOCIAL',
#   'NaN',
#   '0',
#   'Varies with device',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 27, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Daddyhunt: Gay Dating',
#   'SOCIAL',
#   '3.9',
#   '6450',
#   '14M',
#   '500,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'January 22, 2018',
#   '1.3.5',
#   '4.0 and up'],
#  ['Daily Murli Saar Widget',
#   'SOCIAL',
#   '4.6',
#   '308',
#   '454k',
#   '10,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 10, 2015',
#   '1.0',
#   '3.0 and up'],
#  ['Dating App, Flirt & Chat : W-Match',
#   'SOCIAL',
#   '4.3',
#   '175722',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Dating.dk',
#   'SOCIAL',
#   '3.7',
#   '2111',
#   '11M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 6, 2018',
#   '4.1.23',
#   '4.4 and up'],
#  ['Digi-TV.ch',
#   'SOCIAL',
#   'NaN',
#   '62',
#   '25M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 3, 2018',
#   '7.1.29',
#   '4.2 and up'],
#  ['Discípulos em BH',
#   'SOCIAL',
#   'NaN',
#   '24',
#   '5.2M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'February 24, 2018',
#   '1.1.4',
#   '4.1 and up'],
#  ['Downloader plus for FB',
#   'SOCIAL',
#   'NaN',
#   '4',
#   '5.1M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'December 23, 2017',
#   '1.3',
#   '4.2 and up'],
#  ['Dp For Whatsapp',
#   'SOCIAL',
#   '4.3',
#   '39',
#   '12M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'April 13, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  ['Dp for Facebook',
#   'SOCIAL',
#   '4.1',
#   '56',
#   '10M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 16, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  ['Dr B R Ambedkar (Jai Bhim)',
#   'SOCIAL',
#   '4.7',
#   '2068',
#   '7.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'April 13, 2014',
#   '1.0',
#   '2.2 and up'],
#  ['Dr. B.R.Ambedkar',
#   'SOCIAL',
#   '4.8',
#   '1902',
#   '5.2M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 5, 2014',
#   '1.3',
#   '2.1 and up'],
#  ['EG Way Life',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '1.1M',
#   '50+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'April 27, 2016',
#   '1.0',
#   '4.1 and up'],
#  ['EO RAIPUR',
#   'SOCIAL',
#   'NaN',
#   '1',
#   '4.2M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 21, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  ['EXO-L Amino for EXO Fans',
#   'SOCIAL',
#   '4.9',
#   '5677',
#   '67M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['EZ Video Download for Facebook',
#   'SOCIAL',
#   '4.1',
#   '34079',
#   '1.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 14, 2017',
#   '2.001',
#   '4.0.3 and up'],
#  ['Eddsworld Amino',
#   'SOCIAL',
#   '4.9',
#   '3071',
#   '63M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['Ek Maratha',
#   'SOCIAL',
#   '4.8',
#   '725',
#   '3.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'October 12, 2016',
#   '7.5.3',
#   '2.2 and up'],
#  ['Equestria Amino for MLP',
#   'SOCIAL',
#   '4.8',
#   '8369',
#   '63M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['Eternal Light AG',
#   'SOCIAL',
#   '5.0',
#   '30',
#   '13M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 19, 2018',
#   '1.04',
#   '4.0.3 and up'],
#  ['European Solidarity Corps',
#   'SOCIAL',
#   '3.6',
#   '9',
#   '21M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 5, 2018',
#   '1.2.0',
#   '4.4 and up'],
#  ['Evasion.bz',
#   'SOCIAL',
#   '4.1',
#   '8',
#   '4.4M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 14, 2017',
#   '0.0.9',
#   '4.1 and up'],
#  ['FB Advanced Search',
#   'SOCIAL',
#   'NaN',
#   '2',
#   '11M',
#   '50+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 21, 2018',
#   '1.1.1',
#   '4.4 and up'],
#  ['FCB Connect - FC Barcelona',
#   'SOCIAL',
#   '4.5',
#   '795',
#   '21M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 7, 2018',
#   '2.1.5',
#   '4.1 and up'],
#  ['Facebook',
#   'SOCIAL',
#   '4.1',
#   '78158306',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Facebook Creator',
#   'SOCIAL',
#   '4.2',
#   '3895',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 27, 2018',
#   '176.0.0.29.0',
#   '4.4 and up'],
#  ['Facebook Lite',
#   'SOCIAL',
#   '4.3',
#   '8606259',
#   'Varies with device',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Facebook Local',
#   'SOCIAL',
#   '4.2',
#   '4751',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 30, 2018',
#   '13.0',
#   '4.1 and up'],
#  ['Fake Chat (Direct Message)',
#   'SOCIAL',
#   '4.4',
#   '5985',
#   '5.9M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 6, 2017',
#   '1.4.2',
#   '4.1 and up'],
#  ['Fame Boom for Real Followers, Likes',
#   'SOCIAL',
#   '4.7',
#   '896118',
#   '6.6M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'October 9, 2017',
#   '1.3.0',
#   '4.1 and up'],
#  ['Family GPS tracker KidControl + GPS by SMS Locator',
#   'SOCIAL',
#   '4.5',
#   '57146',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 27, 2018',
#   'Varies with device',
#   '4.0.3 and up'],
#  ['Faster Social for Facebook',
#   'SOCIAL',
#   '4.2',
#   '1236',
#   '3.3M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 2, 2018',
#   '1.8',
#   '4.3 and up'],
#  ['Faster for Facebook Lite',
#   'SOCIAL',
#   '4.3',
#   '24456',
#   '4.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 29, 2018',
#   '4.7',
#   '4.1 and up'],
#  ['Fiesta by Tango - Find, Meet and Make New Friends',
#   'SOCIAL',
#   '4.3',
#   '112223',
#   '34M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 5, 2018',
#   '5.68.1',
#   '5.0 and up'],
#  ['Find My Friends',
#   'SOCIAL',
#   '4.2',
#   '305367',
#   '46M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 1, 2018',
#   '16.7.1',
#   '4.4 and up'],
#  ['FollowMeter for Instagram',
#   'SOCIAL',
#   '4.4',
#   '90082',
#   '8.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 22, 2018',
#   '2.44',
#   '4.1 and up'],
#  ['Fr Daoud Lamei',
#   'SOCIAL',
#   '4.7',
#   '2036',
#   '6.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 20, 2018',
#   '1.72',
#   '4.0.3 and up'],
#  ['Frases Cristianas de Esperanza y Fe',
#   'SOCIAL',
#   'NaN',
#   '2',
#   '5.6M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'October 18, 2017',
#   '1.0',
#   '2.3 and up'],
#  ['Free Messages, Video, Chat,Text for Messenger Plus',
#   'SOCIAL',
#   '4.3',
#   '6086',
#   '3.1M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 14, 2018',
#   '1.0.9',
#   '4.3 and up'],
#  ['Free phone calls, free texting SMS on free number',
#   'SOCIAL',
#   '4.5',
#   '412888',
#   '35M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 31, 2018',
#   '3.8.1',
#   '4.1 and up'],
#  ['Friendly for Facebook',
#   'SOCIAL',
#   '4.5',
#   '42621',
#   '23M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 7, 2018',
#   '2.1.05',
#   '4.4 and up'],
#  ['Frim: get new friends on local chat rooms',
#   'SOCIAL',
#   '4.0',
#   '88486',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'March 23, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Frontback - Social Photos',
#   'SOCIAL',
#   '3.8',
#   '19446',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'December 1, 2017',
#   '3.4.5',
#   '4.0.3 and up'],
#  ['FunForMobile Ringtones & Chat',
#   'SOCIAL',
#   '4.4',
#   '68358',
#   '7.2M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'May 7, 2016',
#   '3.22',
#   '4.1 and up'],
#  ['FutureNet your social app',
#   'SOCIAL',
#   '4.2',
#   '2093',
#   '7.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 8, 2018',
#   '3.36',
#   '4.2 and up'],
#  ['GUYZ - Gay Chat & Gay Dating',
#   'SOCIAL',
#   '4.4',
#   '41269',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'May 10, 2017',
#   '1.3.6.4',
#   '4.0.3 and up'],
#  ['Gayvox - Gay Lesbian Bi Dating',
#   'SOCIAL',
#   '3.4',
#   '3640',
#   '9.1M',
#   '500,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'June 13, 2016',
#   '3.1.9',
#   '2.3 and up'],
#  ['GirlTalk.dk',
#   'SOCIAL',
#   '4.3',
#   '3',
#   '5.3M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'September 22, 2017',
#   '3.1.0',
#   '4.1 and up'],
#  ['Golden telegram',
#   'SOCIAL',
#   '4.3',
#   '374',
#   '20M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 30, 2018',
#   'T4.6.5-tl2.0.1',
#   '4.1 and up'],
#  ['Google+',
#   'SOCIAL',
#   '4.2',
#   '4831125',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Greeting Cards & Wishes',
#   'SOCIAL',
#   '4.5',
#   '17350',
#   '12M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 18, 2018',
#   '1.078',
#   'Varies with device'],
#  ['Grindr - Gay chat',
#   'SOCIAL',
#   '3.6',
#   '284795',
#   '31M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 3, 2018',
#   '4.1.2',
#   '4.3 and up'],
#  ['H letter images',
#   'SOCIAL',
#   'NaN',
#   '17',
#   '8.5M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 28, 2018',
#   '16.7',
#   '4.0.3 and up'],
#  ['HOLLA Live: Meet New People via Random Video Chat',
#   'SOCIAL',
#   '4.6',
#   '216513',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 6, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['HTC Social Plugin - Facebook',
#   'SOCIAL',
#   '3.6',
#   '13223',
#   '2.8M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'June 8, 2016',
#   '8.00.752746',
#   '4.4 and up'],
#  ['Hashtags For Likes.co',
#   'SOCIAL',
#   '4.3',
#   '420',
#   '18M',
#   '50,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'December 19, 2016',
#   '1.1',
#   '4.0.3 and up'],
#  ['Hide Something - Photo, Video',
#   'SOCIAL',
#   '4.6',
#   '225103',
#   '5.3M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 13, 2018',
#   '5.1.1',
#   '4.1 and up'],
#  ['Hornet - Gay Social Network',
#   'SOCIAL',
#   '4.0',
#   '163679',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Hum Ek Hain 2.02',
#   'SOCIAL',
#   '5.0',
#   '2',
#   '1.8M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 18, 2018',
#   '1.0',
#   '5.0 and up'],
#  ['Instachat 😜',
#   'SOCIAL',
#   '4.0',
#   '80987',
#   '25M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 30, 2018',
#   '2.2.4',
#   '4.4 and up'],
#  ['Instagram',
#   'SOCIAL',
#   '4.5',
#   '66577446',
#   'Varies with device',
#   '1,000,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Instant DP Downloader for Instagram',
#   'SOCIAL',
#   '4.7',
#   '38',
#   '4.1M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 4, 2018',
#   '1.0.4',
#   '4.2 and up'],
#  ['Jamaa Amino for Animal Jam',
#   'SOCIAL',
#   '4.7',
#   '3873',
#   '63M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['Jaumo Dating, Flirt & Live Video',
#   'SOCIAL',
#   '4.4',
#   '900064',
#   '13M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 31, 2018',
#   '4.17.2',
#   '4.1 and up'],
#  ['Jodel - The Hyperlocal App',
#   'SOCIAL',
#   '4.5',
#   '76480',
#   '20M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 6, 2018',
#   '4.95.4',
#   '5.0 and up'],
#  ['Join R, Community Engagement',
#   'SOCIAL',
#   '4.7',
#   '144',
#   '12M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'January 31, 2017',
#   '1.0.12',
#   '4.0.3 and up'],
#  ['KDRAMA Amino for K-Drama Fans',
#   'SOCIAL',
#   '4.6',
#   '4046',
#   '63M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['KPOP Amino for K-Pop Entertainment',
#   'SOCIAL',
#   '4.8',
#   '19047',
#   '63M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['Kate Mobile for VK',
#   'SOCIAL',
#   '4.4',
#   '540930',
#   '5.3M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 23, 2018',
#   '50.2 lite',
#   '2.2 and up'],
#  ['LOVOO',
#   'SOCIAL',
#   '4.0',
#   '852455',
#   '68M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 3, 2018',
#   '27.0',
#   '4.2 and up'],
#  ['Legend - Animate Text in Video',
#   'SOCIAL',
#   '4.5',
#   '228737',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 12, 2016',
#   'Varies with device',
#   'Varies with device'],
#  ['Lesbian Chat & Dating - SPICY',
#   'SOCIAL',
#   '4.5',
#   '63765',
#   '11M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 31, 2018',
#   '4.17.2',
#   '4.1 and up'],
#  ['LinkedIn',
#   'SOCIAL',
#   '4.2',
#   '1225367',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 2, 2018',
#   '4.1.202',
#   '5.0 and up'],
#  ['Lite Messenger for Facebook Lite',
#   'SOCIAL',
#   '3.8',
#   '108',
#   '2.8M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 28, 2018',
#   '3.1',
#   '4.2 and up'],
#  ['LiveMe - Video chat, new friends, and make money',
#   'SOCIAL',
#   '4.5',
#   '457197',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Love Images',
#   'SOCIAL',
#   '4.3',
#   '16404',
#   '2.3M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 24, 2018',
#   '1.6',
#   '2.3 and up'],
#  ['Love Sticker',
#   'SOCIAL',
#   '4.6',
#   '33177',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 12, 2018',
#   '2.1.6',
#   '4.0 and up'],
#  ['MB Notifications for FB (Free)',
#   'SOCIAL',
#   '3.9',
#   '3047',
#   '1.5M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'April 29, 2015',
#   '1.17.0',
#   '2.3 and up'],
#  ['Mali J',
#   'SOCIAL',
#   '3.2',
#   '185',
#   '4.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'October 20, 2017',
#   '1.0.1',
#   '4.1 and up'],
#  ['Media Sosial TNI AU',
#   'SOCIAL',
#   'NaN',
#   '88',
#   '4.3M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'January 24, 2018',
#   '1.2',
#   '2.1 and up'],
#  ['Meet U - Get Friends for Snapchat, Kik & Instagram',
#   'SOCIAL',
#   '4.6',
#   '4435',
#   '5.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'May 25, 2018',
#   '1.0.3386',
#   '4.0.3 and up'],
#  ['Meet – Talk to Strangers Using Random Video Chat',
#   'SOCIAL',
#   '4.6',
#   '60562',
#   '15M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 6, 2018',
#   '1.3.2',
#   '4.3 and up'],
#  ['MeetMe: Chat & Meet New People',
#   'SOCIAL',
#   '4.2',
#   '1259894',
#   '76M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 3, 2018',
#   'Varies with device',
#   '4.1 and up'],
#  ['Meetup',
#   'SOCIAL',
#   '4.2',
#   '79130',
#   '23M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 2, 2018',
#   '3.10.26',
#   '4.4 and up'],
#  ['Message AI - Write Better Messages (Free)',
#   'SOCIAL',
#   '3.7',
#   '3',
#   '7.9M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 4, 2018',
#   '1.3.1-lite',
#   '5.0 and up'],
#  ['Messages, Text and Video Chat for Messenger',
#   'SOCIAL',
#   '4.4',
#   '49580',
#   '4.0M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 4, 2018',
#   '1.24',
#   '4.1 and up'],
#  ['Messenger',
#   'SOCIAL',
#   '4.1',
#   '68025',
#   '3.9M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'April 16, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['Messenger Messenger',
#   'SOCIAL',
#   '4.3',
#   '38826',
#   '7.0M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 7, 2018',
#   '1.6',
#   '4.1 and up'],
#  ['Messenger Pro',
#   'SOCIAL',
#   '4.4',
#   '13762',
#   '3.9M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 9, 2018',
#   '1.0.2',
#   '4.1 and up'],
#  ['Mico- Stranger Chat Random video Chat, Live, Meet',
#   'SOCIAL',
#   '4.4',
#   '624557',
#   '56M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 27, 2018',
#   '5.4.7.1',
#   '4.3 and up'],
#  ['Mini for Facebook lite',
#   'SOCIAL',
#   '4.1',
#   '260',
#   '1.3M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 21, 2018',
#   '1.2',
#   '3.0 and up'],
#  ['Mirrativ: Live Stream Any App',
#   'SOCIAL',
#   '4.1',
#   '17955',
#   '89M',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 2, 2018',
#   '7.23.4',
#   '4.1 and up'],
#  ['MobilePatrol Public Safety App',
#   'SOCIAL',
#   '4.0',
#   '22695',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone 10+',
#   'Social',
#   'June 21, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Moment',
#   'SOCIAL',
#   '4.5',
#   '19583',
#   '37M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 1, 2018',
#   '5.2.1',
#   '4.4 and up'],
#  ['Movement BE',
#   'SOCIAL',
#   '5.0',
#   '20',
#   '1.2M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'November 10, 2016',
#   '1.2',
#   '4.4 and up'],
#  ['Myjob@BM',
#   'SOCIAL',
#   'NaN',
#   '1',
#   'Varies with device',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 13, 2018',
#   '1.16.21',
#   '4.1 and up'],
#  ['Naruto & Boruto FR',
#   'SOCIAL',
#   'NaN',
#   '7',
#   '7.7M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'February 2, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['News Dz',
#   'SOCIAL',
#   'NaN',
#   '3',
#   '9.9M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 19, 2017',
#   '1.0',
#   '4.0 and up'],
#  ['Nextdoor - Local neighborhood news & classifieds',
#   'SOCIAL',
#   '4.3',
#   '51504',
#   '20M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 25, 2018',
#   '2.69',
#   '5.0 and up'],
#  ['Noticias DF',
#   'SOCIAL',
#   'NaN',
#   '2',
#   '2.3M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 25, 2015',
#   '1.0',
#   '2.3 and up'],
#  ['Otto DM',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '2.4M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 7, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['POF Free Dating App',
#   'SOCIAL',
#   '4.2',
#   '1175815',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 31, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Path',
#   'SOCIAL',
#   '4.4',
#   '1520959',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 9, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Patook - make platonic friends',
#   'SOCIAL',
#   '4.0',
#   '3677',
#   '50M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'June 21, 2018',
#   '10.6.3',
#   '5.0 and up'],
#  ['Pekalongan CJ',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '5.9M',
#   '0+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 21, 2018',
#   '0.0.1',
#   '4.4 and up'],
#  ['Periscope - Live Video',
#   'SOCIAL',
#   '4.0',
#   '479939',
#   '15M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 9, 2018',
#   '1.23.3.0',
#   '4.4 and up'],
#  ['Phoenix - Facebook & Messenger',
#   'SOCIAL',
#   '4.3',
#   '9606',
#   '3.4M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 18, 2018',
#   '2.2.0717',
#   '5.0 and up'],
#  ['Phone Tracker : Family Locator',
#   'SOCIAL',
#   '4.3',
#   '231446',
#   '5.4M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 2, 2018',
#   '4.81',
#   '4.0 and up'],
#  ['Pink Color for Facebook',
#   'SOCIAL',
#   '4.1',
#   '5285',
#   '4.0M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 1, 2018',
#   '2.0.5',
#   '4.1 and up'],
#  ['Pinterest',
#   'SOCIAL',
#   '4.6',
#   '4305441',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Profile Pictures and DP for Whatsapp',
#   'SOCIAL',
#   '4.3',
#   '48',
#   '11M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 12, 2017',
#   '1.3',
#   '4.0.3 and up'],
#  ['Profile Tracker - Who Viewed My Facebook Profile',
#   'SOCIAL',
#   '4.7',
#   '37090',
#   '4.8M',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 1, 2018',
#   '5.4',
#   '4.1 and up'],
#  ['Puffin for Facebook',
#   'SOCIAL',
#   '4.0',
#   '10743',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'December 28, 2017',
#   '7.0.4.17908',
#   '4.1 and up'],
#  ['Qeek for Instagram - Zoom profile insta DP',
#   'SOCIAL',
#   '4.6',
#   '12111',
#   '9.1M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 3, 2018',
#   '1.47',
#   '4.3 and up'],
#  ['Quora',
#   'SOCIAL',
#   '4.5',
#   '313633',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 25, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Rande.cz',
#   'SOCIAL',
#   '3.2',
#   '398',
#   '2.2M',
#   '50,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'December 3, 2014',
#   '1.0.1',
#   '2.3.3 and up'],
#  ['Reisedealz.eu',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '10M',
#   '10+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'September 24, 2015',
#   '1.0',
#   '4.0 and up'],
#  ['Rejoin Your Ex',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '29M',
#   '100+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 26, 2015',
#   '2.0',
#   '2.3.3 and up'],
#  ['SKOUT - Meet, Chat, Go Live',
#   'SOCIAL',
#   '4.3',
#   '1064076',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 28, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['SPARK - Live random video chat & meet new people',
#   'SOCIAL',
#   '4.6',
#   '79658',
#   '17M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 6, 2018',
#   '2.1.3.2',
#   '4.3 and up'],
#  ['Sabka Malik Ek Sai',
#   'SOCIAL',
#   '4.2',
#   '17',
#   '5.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 25, 2013',
#   '1.3',
#   '2.2 and up'],
#  ['SayHi Chat, Meet New People',
#   'SOCIAL',
#   '4.2',
#   '423138',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 9, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['See U - Random video chat, video chat',
#   'SOCIAL',
#   '4.1',
#   '568',
#   '27M',
#   '100,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'April 13, 2018',
#   '1.4.1',
#   '4.1 and up'],
#  ['Share G - Images Sharing - Wallpapers App',
#   'SOCIAL',
#   '4.4',
#   '120',
#   '2.3M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'October 5, 2017',
#   '1.0',
#   '4.0.3 and up'],
#  ['Snaappy – 3D fun AR core communication platform',
#   'SOCIAL',
#   '4.6',
#   '16801',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 16, 2018',
#   '1.5.341',
#   '4.0.3 and up'],
#  ['Snapchat',
#   'SOCIAL',
#   '4.0',
#   '17015352',
#   'Varies with device',
#   '500,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 30, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Social network all in one 2018',
#   'SOCIAL',
#   '4.3',
#   '1403',
#   '3.7M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'January 30, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['Stickers for Facebook',
#   'SOCIAL',
#   '4.3',
#   '11066',
#   '10M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'March 13, 2018',
#   '1.4',
#   '4.4 and up'],
#  ['Stickers for Imo, fb, whatsapp',
#   'SOCIAL',
#   '4.4',
#   '214',
#   '8.7M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'October 23, 2016',
#   '1.0.0.2',
#   '2.3 and up'],
#  ['Stream - Live Video Community',
#   'SOCIAL',
#   '4.1',
#   '6388',
#   'Varies with device',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'December 5, 2017',
#   'Varies with device',
#   'Varies with device'],
#  ['Students.ch',
#   'SOCIAL',
#   'NaN',
#   '5',
#   'Varies with device',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 11, 2018',
#   '1.0.12',
#   '4.0 and up'],
#  ['Swift for Facebook Lite',
#   'SOCIAL',
#   '4.3',
#   '9562',
#   '5.8M',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 31, 2018',
#   '4.1.0',
#   'Varies with device'],
#  ['TN EC Online New',
#   'SOCIAL',
#   'NaN',
#   '7',
#   '2.3M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 21, 2018',
#   '2.1',
#   '4.0 and up'],
#  ['TN Patta /Chitta /EC New',
#   'SOCIAL',
#   '4.8',
#   '5',
#   '3.0M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 20, 2018',
#   '1.0',
#   '4.0 and up'],
#  ['TN e Sevai TN EB Bill Patta Citta EC Birth All Hub',
#   'SOCIAL',
#   '3.7',
#   '23',
#   '16M',
#   '5,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'April 26, 2018',
#   '1.0',
#   '4.1 and up'],
#  ['TNEB Bill Online Payment (Tamil)',
#   'SOCIAL',
#   'NaN',
#   '7',
#   '2.3M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '2.0',
#   '4.0.3 and up'],
#  ['Tagged - Meet, Chat & Dating',
#   'SOCIAL',
#   '4.1',
#   '486830',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'June 21, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Tango - Live Video Broadcast',
#   'SOCIAL',
#   '4.3',
#   '3806669',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Tapatalk - 100,000+ Forums',
#   'SOCIAL',
#   '4.1',
#   '285820',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'June 19, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Telegram X',
#   'SOCIAL',
#   '4.6',
#   '70616',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 27, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Text Free: WiFi Calling App',
#   'SOCIAL',
#   '4.2',
#   '83488',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 24, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Text Me: Text Free, Call Free, Second Phone Number',
#   'SOCIAL',
#   '4.3',
#   '344921',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 7, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Text free - Free Text + Call',
#   'SOCIAL',
#   '4.3',
#   '315441',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 26, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['TextNow - free text + calls',
#   'SOCIAL',
#   '4.4',
#   '441189',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['The Messenger App',
#   'SOCIAL',
#   '4.4',
#   '4919',
#   '2.8M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 3, 2018',
#   '0.1.1',
#   '4.1 and up'],
#  ['The Video Messenger App',
#   'SOCIAL',
#   '4.4',
#   '1200',
#   '2.8M',
#   '100,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 2, 2018',
#   '0.1.1',
#   '4.1 and up'],
#  ['Tik Tok - including musical.ly',
#   'SOCIAL',
#   '4.4',
#   '5637451',
#   '59M',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 3, 2018',
#   '8.0.0',
#   '4.1 and up'],
#  ['Timehop',
#   'SOCIAL',
#   '4.1',
#   '161610',
#   '16M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 5, 2018',
#   '4.5.3',
#   '4.1 and up'],
#  ['Tumblr',
#   'SOCIAL',
#   '4.4',
#   '2955326',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 1, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['TwitCasting Live',
#   'SOCIAL',
#   '3.6',
#   '14835',
#   'Varies with device',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['U LIVE – Video Chat & Stream',
#   'SOCIAL',
#   '4.5',
#   '67611',
#   '21M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'April 23, 2018',
#   '263.16.29',
#   '4.0.3 and up'],
#  ['U-Report',
#   'SOCIAL',
#   '4.3',
#   '241',
#   '7.5M',
#   '10,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'April 10, 2018',
#   '2.8.4',
#   '4.0.3 and up'],
#  ['UP EB Bill Payment & Details',
#   'SOCIAL',
#   '5.0',
#   '3',
#   '2.4M',
#   '50+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 11, 2018',
#   '2.0',
#   '4.0 and up'],
#  ['Undertale AU Amino',
#   'SOCIAL',
#   '4.8',
#   '5369',
#   '63M',
#   '50,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 13, 2018',
#   '1.8.19106',
#   '4.0.3 and up'],
#  ['Unlimited Group Links - Whatsapp, FB, Telegram',
#   'SOCIAL',
#   '3.4',
#   '44',
#   '2.8M',
#   '10,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'July 3, 2018',
#   '4.0',
#   '4.0.3 and up'],
#  ['V Bucks ProTips New',
#   'SOCIAL',
#   '4.7',
#   '594',
#   '3.6M',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 19, 2018',
#   '1.0',
#   '2.1 and up'],
#  ['VK',
#   'SOCIAL',
#   '3.8',
#   '5793284',
#   'Varies with device',
#   '100,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 3, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['VMate Lite - Funny Short Videos Social Network',
#   'SOCIAL',
#   '4.3',
#   '903',
#   '4.6M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 3, 2018',
#   '1.76',
#   '4.0.3 and up'],
#  ['Verdad o Reto',
#   'SOCIAL',
#   '3.8',
#   '826',
#   '5.1M',
#   '500,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'May 10, 2018',
#   '2.0',
#   '4.1 and up'],
#  ['VidStatus app - Status Videos & Status Downloader',
#   'SOCIAL',
#   '4.5',
#   '25562',
#   '31M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 2, 2018',
#   '2.6.10',
#   '4.1 and up'],
#  ['Waplog - Free Chat, Dating App, Meet Singles',
#   'SOCIAL',
#   '4.2',
#   '522018',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['We Heart It',
#   'SOCIAL',
#   '4.5',
#   '637309',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 18, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Web Browser & Fast Explorer',
#   'SOCIAL',
#   '4.4',
#   '54768',
#   '2.6M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 16, 2018',
#   '3.6.1',
#   '4.0.3 and up'],
#  ['Web Browser ( Fast & Secure Web Explorer)',
#   'SOCIAL',
#   '4.4',
#   '2508',
#   '6.0M',
#   '500,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'November 20, 2017',
#   '2.0.1',
#   '4.0.3 and up'],
#  ['What U See',
#   'SOCIAL',
#   '4.0',
#   '712',
#   '21M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'March 5, 2018',
#   '2.3.9',
#   '4.1 and up'],
#  ['Whisper',
#   'SOCIAL',
#   '4.1',
#   '205803',
#   'Varies with device',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 18, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['Who Viewed My Facebook Profile - Stalkers Visitors',
#   'SOCIAL',
#   '4.6',
#   '273244',
#   '9.9M',
#   '5,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 24, 2018',
#   '4.1.1',
#   '4.0.3 and up'],
#  ['Wishbone - Compare Anything',
#   'SOCIAL',
#   '4.3',
#   '51569',
#   '26M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 30, 2018',
#   '5.4.7',
#   '4.1 and up'],
#  ['YAY - TBH',
#   'SOCIAL',
#   '4.1',
#   '2520',
#   '12M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'November 17, 2017',
#   '1.1.5',
#   '4.3 and up'],
#  ['YouNow: Live Stream Video Chat',
#   'SOCIAL',
#   '4.1',
#   '309872',
#   '85M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'August 3, 2018',
#   '14.0.13',
#   '4.1 and up'],
#  ['Zdravei.BG',
#   'SOCIAL',
#   'NaN',
#   '6',
#   '6.1M',
#   '1,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'January 8, 2018',
#   '3.7.17',
#   '4.1 and up'],
#  ['Zello PTT Walkie Talkie',
#   'SOCIAL',
#   '4.4',
#   '695613',
#   'Varies with device',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'August 2, 2018',
#   'Varies with device',
#   'Varies with device'],
#  ['bm-Events',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '8.1M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'November 1, 2016',
#   '1.1.1',
#   '4.4 and up'],
#  ['eChallan Andhra Pradesh (AP)',
#   'SOCIAL',
#   '3.0',
#   '5',
#   '2.6M',
#   '1,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'February 15, 2018',
#   '1.0.0.4',
#   '4.1 and up'],
#  ['funny Image Comments for FB',
#   'SOCIAL',
#   '3.9',
#   '19',
#   '15M',
#   '5,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'February 13, 2018',
#   '2.0',
#   '4.1 and up'],
#  ['i-share AF/KLM (AFKL ishare)',
#   'SOCIAL',
#   'NaN',
#   '2',
#   '53M',
#   '100+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'July 21, 2018',
#   '1.16.5',
#   '4.1 and up'],
#  ['iCard BD Plus',
#   'SOCIAL',
#   '5.0',
#   '2',
#   '2.4M',
#   '500+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 15, 2016',
#   '3.7.5',
#   '2.0 and up'],
#  ['magicApp Calling & Messaging',
#   'SOCIAL',
#   '4.1',
#   '207712',
#   'Varies with device',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'June 9, 2018',
#   '4.18.962.5',
#   '2.3 and up'],
#  ['ooVoo Video Calls, Messaging & Stories',
#   'SOCIAL',
#   '4.3',
#   '1157004',
#   '34M',
#   '50,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'October 16, 2017',
#   '4.2.1',
#   '4.3 and up'],
#  ['pixiv',
#   'SOCIAL',
#   '4.2',
#   '86956',
#   '24M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Mature 17+',
#   'Social',
#   'August 3, 2018',
#   '5.0.109',
#   '4.4 and up'],
#  ['quran-DZ',
#   'SOCIAL',
#   'NaN',
#   '0',
#   '6.2M',
#   '10+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'June 13, 2018',
#   '1.1',
#   '4.2 and up'],
#  ['signály.cz',
#   'SOCIAL',
#   'NaN',
#   '38',
#   '881k',
#   '1,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'May 9, 2013',
#   '1.1',
#   '2.2 and up'],
#  ['textPlus: Free Text & Calls',
#   'SOCIAL',
#   '4.1',
#   '382121',
#   '28M',
#   '10,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 26, 2018',
#   '7.3.1',
#   '4.1 and up'],
#  ['uCiC- Videos and Photos on demand',
#   'SOCIAL',
#   '4.0',
#   '2052',
#   '7.0M',
#   '100,000+',
#   'Free',
#   '0',
#   'Teen',
#   'Social',
#   'September 27, 2017',
#   '2.16',
#   '4.4 and up'],
#  ['💘 WhatsLov: Smileys of love, stickers and GIF',
#   'SOCIAL',
#   '4.6',
#   '22098',
#   '18M',
#   '1,000,000+',
#   'Free',
#   '0',
#   'Everyone',
#   'Social',
#   'July 24, 2018',
#   '4.2.4',
#   '4.0.3 and up']]

# %% [markdown]
# **Social apps category includes all the big social media apps, like Facebook, Twitter, Instagram and tools for a better use of those.**

# %% [markdown]
# **Let' check the apps competition on these three categories.**

# %%
comlen = len (communication_apps)
vilen = len (video_players_apps)
soclen = len (social_apps)

print (comlen)
print (vilen)
print (soclen)
# Out:
# 287
# 159
# 236

# %% [markdown]
# **With 287 entries, the category with more apps competing for user visibility is "Communication". Besides the competition, this genre also has some big and well-stablished players, and by elimination, we concluded we should look somewhere else for better opportunities.**

# %% [markdown]
# **The "Social" apps category is the second more competitive. We found some big players there too.**

# %% [markdown]
# **By elimination, we indicate the "video players" category as the best opportunity for developing an app.**
